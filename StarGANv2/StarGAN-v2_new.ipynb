# %%
 from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "Colab Notebooks/StarGAN-V2"
GOOGLE_DRIVE_PATH = os.path.join('drive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['utils.py', 'ops.py', 'README.md', 'LICENSE', 'networks.py', 'main.py', 'StarGAN_v2.py', '__pycache__', 'checkpoint', 'results', 'logs', 'samples', 'StarGAN-v2_new.ipynb', 'StarGAN-v2.ipynb']

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)

# !pip install tqdm --upgrade
# !pip install Pillow --upgrade

# !python drive/MyDrive/'Colab Notebooks'/StarGAN-V2/main.py --dataset style/ \
          --phase test \
          --iteration 5000 --ds_iter 5000 \
          --batch_size 8 \
          --checkpoint_dir drive/MyDrive/'Colab Notebooks'/StarGAN-V2/checkpoint \
          --result_dir drive/MyDrive/'Colab Notebooks'/StarGAN-V2/results \
          --log_dir drive/MyDrive/'Colab Notebooks'/StarGAN-V2/logs \
          --sample_dir drive/MyDrive/'Colab Notebooks'/StarGAN-V2/samples
# Out:
# Requirement already up-to-date: tqdm in /usr/local/lib/python3.6/dist-packages (4.54.1)
# Requirement already up-to-date: Pillow in /usr/local/lib/python3.6/dist-packages (8.0.1)
# 2020-12-16 23:32:05.826062: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-12-16 23:32:07.499015: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-12-16 23:32:07.508569: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-12-16 23:32:07.508623: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (cbae7eff0869): /proc/driver/nvidia/version does not exist
#
# ##### Information #####
# # gan type :  gan-gp
# # dataset :  style/
# # domain_list :  []
# # batch_size :  8
# # max iteration :  5000
# # ds iteration :  5000
#
# ##### Generator #####
# # latent_dim :  16
# # style_dim :  64
# # num_style :  5
#
# ##### Mapping Network #####
# # hidden_dim :  512
#
# ##### Discriminator #####
# # spectral normalization :  False
# Dataset number :  0
# 2020-12-16 23:32:07.518757: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-12-16 23:32:07.518996: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2766a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-12-16 23:32:07.519034: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# Traceback (most recent call last):
#   File "drive/MyDrive/Colab Notebooks/StarGAN-V2/main.py", line 117, in <module>
#     main()
#   File "drive/MyDrive/Colab Notebooks/StarGAN-V2/main.py", line 103, in main
#     gan.build_model()
#   File "/content/drive/MyDrive/Colab Notebooks/StarGAN-V2/StarGAN_v2.py", line 137, in build_model
#     img_and_domain = img_and_domain.shuffle(buffer_size=dataset_num, reshuffle_each_iteration=True).repeat()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 1240, in shuffle
#     return ShuffleDataset(self, buffer_size, seed, reshuffle_each_iteration)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py", line 3676, in __init__
#     **self._flat_structure)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_dataset_ops.py", line 6215, in shuffle_dataset_v3
#     _ops.raise_from_not_ok_status(e, name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py", line 6843, in raise_from_not_ok_status
#     six.raise_from(core._status_to_exception(e.code, message), None)
#   File "<string>", line 3, in raise_from
# tensorflow.python.framework.errors_impl.InvalidArgumentError: buffer_size must be greater than zero. [Op:ShuffleDatasetV3]
