# %% [markdown]
# # StarGAN Version 1
#
# This notebook is for implementing `StarGAN` from the paper [StarGAN: Unified Generative Adversarial Networks for Multi-Domain Image-to-Image Translation](https://arxiv.org/abs/1711.09020).
#
# * Credit: Ziqiao Ma
# * Latest Update: Dec.13 2020
# * Reference: [Official Implementation](https://github.com/yunjey/stargan) and [hwalsuklee's Github](https://github.com/hwalsuklee/tensorflow-generative-model-collections).

# %% [markdown]
# ## Colab Setup

# %% [markdown]
# ### Environment Configuration

# %% [markdown]
# Mount to Colab and set up autoreload module.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# TODO: Change the variable to the locaation of your file in the drive!

# %%
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'Colab Notebooks/StarGAN'

# %%
import os
import sys
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

GOOGLE_DRIVE_PATH = os.path.join('drive', 'MyDrive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
sys.path.append(GOOGLE_DRIVE_PATH)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['StarGANv1.ipynb']

# %% [markdown]
# Set up file system.

# %%
# Create model and log
# !mkdir stargan/
# !mkdir stargan/samples/
# !mkdir stargan/results/
# !mkdir stargan/models/
# !mkdir stargan/logs/

# Create data/
# !mkdir data/
# !mkdir data/style/
# !mkdir data/style/train/
# !mkdir data/style/test/

# !ls
# !ls stargan
# !ls data
# Out:
# data  drive  sample_data  stargan
# logs  models  results  samples
# style

# %% [markdown]
# ### Import Libraries

# %%
import argparse
import random
import glob
import time
import datetime
import copy

import matplotlib.pyplot as plt

import numpy as np

import tensorflow as tf
import tensorflow_datasets as tfds

import torch
from torch.backends import cudnn
from torch.utils import data
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F

from torchvision import transforms as T
from torchvision.utils import save_image
from torchvision.datasets import ImageFolder

import cv2
from PIL import Image

# %% [markdown]
# ## Parameters and Helpers

# %% [markdown]
# ### Global Parameters

# %%
LABEL_DIM = 5
BUFFER_SIZE = 1000
CROP_SIZE = 256
IMG_SIZE = 256
IMG_WIDTH = IMG_SIZE
IMG_HEIGHT = IMG_SIZE

AUTOTUNE = tf.data.experimental.AUTOTUNE

TRAIN_IMG_DIR = 'data/style/train'
TEST_IMG_DIR = 'data/style/test'

def str2bool(v):
    return v.lower() in ('true')

def set_seed(seed):
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

SEED = 0
set_seed(SEED)

# %% [markdown]
# ### TensorFlow Logger

# %%
class Logger(object):
    """Tensorboard logger for v2.0."""

    def __init__(self, log_dir):
        """Initialize summary writer."""
        self.writer = tf.summary.create_file_writer(log_dir)

    def scalar_summary(self, tag, value, step):
        """Add scalar summary."""
        with self.writer.as_default():
            tf.summary.scalar(tag, value, step=step)
            self.writer.flush()

# %% [markdown]
# ## Data and Preprocessing

# %% [markdown]
# ### Style Dataset
# Get the Style dataset from tensorflow API.

# %%
dataset, metadata = tfds.load('cycle_gan/ukiyoe2photo', with_info=True, as_supervised=True)

train_ukiyoe, train_photo = dataset['trainA'], dataset['trainB']
test_ukiyoe, test_photo = dataset['testA'], dataset['testB']
print("Ukiyoe training dataset Length: {}".format(len(train_photo)))
# Out:
# Downloading and preparing dataset cycle_gan/ukiyoe2photo/2.0.0 (download: 279.38 MiB, generated: Unknown size, total: 279.38 MiB) to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0.incompleteY0CQ65/cycle_gan-trainA.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=562.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0.incompleteY0CQ65/cycle_gan-trainB.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=6287.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0.incompleteY0CQ65/cycle_gan-testA.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=263.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0.incompleteY0CQ65/cycle_gan-testB.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=751.0), HTML(value='')))
# Dataset cycle_gan downloaded and prepared to /root/tensorflow_datasets/cycle_gan/ukiyoe2photo/2.0.0. Subsequent calls will reuse this data.
# Ukiyoe training dataset Length: 6287

# %% [markdown]
# #### Preprocessing

# %%
def random_crop(image):
    cropped_image = tf.image.random_crop(
        image, size=[IMG_HEIGHT, IMG_WIDTH, 3])
    return cropped_image

def normalize(image):
    image = tf.cast(image, tf.float32)
    image = (image / 127.5) - 1
    return image

def random_jitter(image):
    # resizing to 286 x 286 x 3
    image = tf.image.resize(image, [286, 286], method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    # randomly cropping to 256 x 256 x 3
    image = random_crop(image)
    # random mirroring
    image = tf.image.random_flip_left_right(image)
    return image

def preprocess_image_train(image, label):
    image = random_jitter(image)
    image = normalize(image)
    return image

def preprocess_image_test(image, label):
    image = normalize(image)
    return image

# %% [markdown]
# #### Visualization

# %%
train_ukiyoe = train_ukiyoe.map(
    preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

train_photo = train_photo.map(
    preprocess_image_train, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

test_ukiyoe = test_ukiyoe.map(
    preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

test_photo = test_photo.map(
    preprocess_image_test, num_parallel_calls=AUTOTUNE).cache().shuffle(
    BUFFER_SIZE).batch(1)

sample_ukiyoe = next(iter(train_ukiyoe))
sample_photo = next(iter(train_photo))

# %%
plt.subplot(121)
plt.title('ukiyoe')
plt.imshow(sample_ukiyoe[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('ukiyoe with random jitter')
plt.imshow(random_jitter(sample_ukiyoe[0]) * 0.5 + 0.5)

# %%
plt.subplot(121)
plt.title('Photo')
plt.imshow(sample_photo[0] * 0.5 + 0.5)

plt.subplot(122)
plt.title('Photo with random jitter')
plt.imshow(random_jitter(sample_photo[0]) * 0.5 + 0.5)

# %% [markdown]
# #### Save image

# %%
# Download Datasets from UCB
# !wget -cO - https://people.eecs.berkeley.edu/%7Etaesung_park/CycleGAN/datasets/cezanne2photo.zip > cezanne.zip
# !wget -cO - https://people.eecs.berkeley.edu/%7Etaesung_park/CycleGAN/datasets/monet2photo.zip > monet.zip
# !wget -cO - https://people.eecs.berkeley.edu/%7Etaesung_park/CycleGAN/datasets/ukiyoe2photo.zip > ukiyoe.zip
# !wget -cO - https://people.eecs.berkeley.edu/%7Etaesung_park/CycleGAN/datasets/vangogh2photo.zip > vangogh.zip

# Unzip files
# !unzip cezanne.zip
# !unzip monet.zip
# !unzip ukiyoe.zip
# !unzip vangogh.zip

# !rm -f cezanne.zip
# !mv cezanne2photo/trainA/ data/style/train/cezanne/
# !mv cezanne2photo/testA/ data/style/test/cezanne/
# !mv cezanne2photo/trainB/ data/style/train/photo/
# !mv cezanne2photo/testB/ data/style/test/photo/
# !rm -r cezanne2photo/

# !rm -f monet.zip
# !mv monet2photo/trainA/ data/style/train/monet/
# !mv monet2photo/testA/ data/style/test/monet/
# !rm -r monet2photo/

# !rm -f ukiyoe.zip
# !mv ukiyoe2photo/trainA/ data/style/train/ukiyoe/
# !mv ukiyoe2photo/testA/ data/style/test/ukiyoe/
# !rm -r ukiyoe2photo/

# !rm -f vangogh.zip
# !mv vangogh2photo/trainA/ data/style/train/vangogh/
# !mv vangogh2photo/testA/ data/style/test/vangogh/
# !rm -r vangogh2photo/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating
#   inflating: vangogh2photo/testA/00707.jpg
#   inflating: vangogh2photo/testA/00270.jpg
#   inflating: vangogh2photo/testA/00405.jpg
#   inflating: vangogh2photo/testA/00203.jpg
#   inflating: vangogh2photo/testA/00393.jpg
#   inflating: vangogh2photo/testA/00655.jpg
#   inflating: vangogh2photo/testA/00519.jpg
#   inflating: vangogh2photo/testA/00670.jpg
#   inflating: vangogh2photo/testA/00474.jpg
#   inflating: vangogh2photo/testA/00354.jpg
#   inflating: vangogh2photo/testA/00297.jpg
#   inflating: vangogh2photo/testA/00439.jpg
#   inflating: vangogh2photo/testA/00697.jpg
#   inflating: vangogh2photo/testA/00050.jpg
#   inflating: vangogh2photo/testA/00373.jpg
#   inflating: vangogh2photo/testA/00430.jpg
#   inflating: vangogh2photo/testA/00401.jpg
#   inflating: vangogh2photo/testA/00371.jpg
#   inflating: vangogh2photo/testA/00277.jpg
#   inflating: vangogh2photo/testA/00545.jpg
#   inflating: vangogh2photo/testA/00457.jpg
#   inflating: vangogh2photo/testA/00705.jpg
#   inflating: vangogh2photo/testA/00428.jpg
#   inflating: vangogh2photo/testA/00229.jpg
#   inflating: vangogh2photo/testA/00295.jpg
#   inflating: vangogh2photo/testA/00053.jpg
#   inflating: vangogh2photo/testA/00353.jpg
#   inflating: vangogh2photo/testA/00042.jpg
#   inflating: vangogh2photo/testA/00134.jpg
#   inflating: vangogh2photo/testA/00054.jpg
#   inflating: vangogh2photo/testA/00427.jpg
#   inflating: vangogh2photo/testA/00335.jpg
#   inflating: vangogh2photo/testA/00293.jpg
#   inflating: vangogh2photo/testA/00413.jpg
#   inflating: vangogh2photo/testA/00643.jpg
#   inflating: vangogh2photo/testA/00316.jpg
#   inflating: vangogh2photo/testA/00425.jpg
#   inflating: vangogh2photo/testA/00314.jpg
#   inflating: vangogh2photo/testA/00093.jpg
#   inflating: vangogh2photo/testA/00303.jpg
#   inflating: vangogh2photo/testA/00376.jpg
#   inflating: vangogh2photo/testA/00057.jpg
#   inflating: vangogh2photo/testA/00397.jpg
#   inflating: vangogh2photo/testA/00165.jpg
#   inflating: vangogh2photo/testA/00271.jpg
#   inflating: vangogh2photo/testA/00044.jpg
#   inflating: vangogh2photo/testA/00496.jpg

# %% [markdown]
# ### CelebA Dataset

# %%
class CelebA(data.Dataset):
    """Dataset class for the CelebA dataset."""

    def __init__(self, image_dir, attr_path, selected_attrs, transform, mode):
        """Initialize and preprocess the CelebA dataset."""
        self.image_dir = image_dir
        self.attr_path = attr_path
        self.selected_attrs = selected_attrs
        self.transform = transform
        self.mode = mode
        self.train_dataset = []
        self.test_dataset = []
        self.attr2idx = {}
        self.idx2attr = {}
        self.preprocess()

        if mode == 'train':
            self.num_images = len(self.train_dataset)
        else:
            self.num_images = len(self.test_dataset)

    def preprocess(self):
        """Preprocess the CelebA attribute file."""
        lines = [line.rstrip() for line in open(self.attr_path, 'r')]
        all_attr_names = lines[1].split()
        for i, attr_name in enumerate(all_attr_names):
            self.attr2idx[attr_name] = i
            self.idx2attr[i] = attr_name

        lines = lines[2:]
        random.seed(1234)
        random.shuffle(lines)
        for i, line in enumerate(lines):
            split = line.split()
            filename = split[0]
            values = split[1:]

            label = []
            for attr_name in self.selected_attrs:
                idx = self.attr2idx[attr_name]
                label.append(values[idx] == '1')

            if (i+1) < 2000:
                self.test_dataset.append([filename, label])
            else:
                self.train_dataset.append([filename, label])

        print('Finished preprocessing the CelebA dataset...')

    def __getitem__(self, index):
        """Return one image and its corresponding attribute label."""
        dataset = self.train_dataset if self.mode == 'train' else self.test_dataset
        filename, label = dataset[index]
        image = Image.open(os.path.join(self.image_dir, filename))
        return self.transform(image), torch.FloatTensor(label)

    def __len__(self):
        """Return the number of images."""
        return self.num_images

# %% [markdown]
# ### Dataloader

# %%
def get_loader(image_dir, attr_path, selected_attrs, crop_size=178, image_size=128, 
               batch_size=16, dataset='CelebA', mode='train', num_workers=1):
    """Build and return a data loader."""
    transform = []
    if mode == 'train':
        transform.append(T.RandomHorizontalFlip())
    transform.append(T.CenterCrop(crop_size))
    transform.append(T.Resize(image_size))
    transform.append(T.ToTensor())
    transform.append(T.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)))
    transform = T.Compose(transform)

    if dataset == 'CelebA':
        dataset = CelebA(image_dir, attr_path, selected_attrs, transform, mode)
    elif dataset == 'RaFD':
        dataset = ImageFolder(image_dir, transform) 

    data_loader = data.DataLoader(dataset=dataset,
                                  batch_size=batch_size,
                                  shuffle=(mode=='train'),
                                  num_workers=num_workers)
    return data_loader

# %% [markdown]
# ## StarGAN Model

# %% [markdown]
# ### ResidualBlock

# %%
class ResidualBlock(nn.Module):
    """
    Residual Block with instance normalization.
    """
    
    def __init__(self, dim_in, dim_out):
        super(ResidualBlock, self).__init__()
        self.main = nn.Sequential(
            nn.Conv2d(dim_in, dim_out, kernel_size=3, stride=1, padding=1, bias=False),
            nn.InstanceNorm2d(dim_out, affine=True, track_running_stats=True),
            nn.ReLU(inplace=True),
            nn.Conv2d(dim_out, dim_out, kernel_size=3, stride=1, padding=1, bias=False),
            nn.InstanceNorm2d(dim_out, affine=True, track_running_stats=True))

    def forward(self, x):
        return x + self.main(x)

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    """
    Generator network.
    """
    
    def __init__(self, conv_dim=64, c_dim=5, repeat_num=6):
        super(Generator, self).__init__()

        layers = []
        layers.append(nn.Conv2d(3+c_dim, conv_dim, kernel_size=7, stride=1, padding=3, bias=False))
        layers.append(nn.InstanceNorm2d(conv_dim, affine=True, track_running_stats=True))
        layers.append(nn.ReLU(inplace=True))

        # Down-sampling layers.
        curr_dim = conv_dim
        for i in range(2):
            layers.append(nn.Conv2d(curr_dim, curr_dim*2, kernel_size=4, stride=2, padding=1, bias=False))
            layers.append(nn.InstanceNorm2d(curr_dim*2, affine=True, track_running_stats=True))
            layers.append(nn.ReLU(inplace=True))
            curr_dim = curr_dim * 2

        # Bottleneck layers.
        for i in range(repeat_num):
            layers.append(ResidualBlock(dim_in=curr_dim, dim_out=curr_dim))

        # Up-sampling layers.
        for i in range(2):
            layers.append(nn.ConvTranspose2d(curr_dim, curr_dim//2, kernel_size=4, stride=2, padding=1, bias=False))
            layers.append(nn.InstanceNorm2d(curr_dim//2, affine=True, track_running_stats=True))
            layers.append(nn.ReLU(inplace=True))
            curr_dim = curr_dim // 2

        layers.append(nn.Conv2d(curr_dim, 3, kernel_size=7, stride=1, padding=3, bias=False))
        layers.append(nn.Tanh())
        self.main = nn.Sequential(*layers)

    def forward(self, x, c):
        # Replicate spatially and concatenate domain information.
        # Note that this type of label conditioning does not work at all if we use reflection padding in Conv2d.
        # This is because instance normalization ignores the shifting (or bias) effect.
        c = c.view(c.size(0), c.size(1), 1, 1)
        c = c.repeat(1, 1, x.size(2), x.size(3))
        x = torch.cat([x, c], dim=1)
        return self.main(x)

# %% [markdown]
# ### Discriminator

# %%
class Discriminator(nn.Module):
    """
    Discriminator network with PatchGAN.
    """
    
    def __init__(self, image_size=128, conv_dim=64, c_dim=5, repeat_num=6):
        super(Discriminator, self).__init__()
        layers = []
        layers.append(nn.Conv2d(3, conv_dim, kernel_size=4, stride=2, padding=1))
        layers.append(nn.LeakyReLU(0.01))

        curr_dim = conv_dim
        for i in range(1, repeat_num):
            layers.append(nn.Conv2d(curr_dim, curr_dim*2, kernel_size=4, stride=2, padding=1))
            layers.append(nn.LeakyReLU(0.01))
            curr_dim = curr_dim * 2

        kernel_size = int(image_size / np.power(2, repeat_num))
        self.main = nn.Sequential(*layers)
        self.conv1 = nn.Conv2d(curr_dim, 1, kernel_size=3, stride=1, padding=1, bias=False)
        self.conv2 = nn.Conv2d(curr_dim, c_dim, kernel_size=kernel_size, bias=False)
        
    def forward(self, x):
        h = self.main(x)
        out_src = self.conv1(h)
        out_cls = self.conv2(h)
        return out_src, out_cls.view(out_cls.size(0), out_cls.size(1))

# %% [markdown]
# ## GAN Solver

# %%
class Solver(object):
    """Solver for training and testing StarGAN."""

    def __init__(self, celeba_loader, rafd_loader, config):
        """Initialize configurations."""

        # Data loader.
        self.celeba_loader = celeba_loader
        self.rafd_loader = rafd_loader

        # Model configurations.
        self.c_dim = config.c_dim
        self.c2_dim = config.c2_dim
        self.image_size = config.image_size
        self.g_conv_dim = config.g_conv_dim
        self.d_conv_dim = config.d_conv_dim
        self.g_repeat_num = config.g_repeat_num
        self.d_repeat_num = config.d_repeat_num
        self.lambda_cls = config.lambda_cls
        self.lambda_rec = config.lambda_rec
        self.lambda_gp = config.lambda_gp

        # Training configurations.
        self.dataset = config.dataset
        self.batch_size = config.batch_size
        self.num_iters = config.num_iters
        self.num_iters_decay = config.num_iters_decay
        self.g_lr = config.g_lr
        self.d_lr = config.d_lr
        self.n_critic = config.n_critic
        self.beta1 = config.beta1
        self.beta2 = config.beta2
        self.resume_iters = config.resume_iters
        self.selected_attrs = config.selected_attrs

        # Test configurations.
        self.test_iters = config.test_iters

        # Miscellaneous.
        self.use_tensorboard = config.use_tensorboard
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Directories.
        self.log_dir = config.log_dir
        self.sample_dir = config.sample_dir
        self.model_save_dir = config.model_save_dir
        self.result_dir = config.result_dir

        # Step size.
        self.log_step = config.log_step
        self.sample_step = config.sample_step
        self.model_save_step = config.model_save_step
        self.lr_update_step = config.lr_update_step

        # Build the model and tensorboard.
        self.build_model()
        if self.use_tensorboard:
            self.build_tensorboard()

    def build_model(self):
        """Create a generator and a discriminator."""
        if self.dataset in ['CelebA', 'RaFD']:
            self.G = Generator(self.g_conv_dim, self.c_dim, self.g_repeat_num)
            self.D = Discriminator(self.image_size, self.d_conv_dim, self.c_dim, self.d_repeat_num) 
        elif self.dataset in ['Both']:
            self.G = Generator(self.g_conv_dim, self.c_dim+self.c2_dim+2, self.g_repeat_num)   # 2 for mask vector.
            self.D = Discriminator(self.image_size, self.d_conv_dim, self.c_dim+self.c2_dim, self.d_repeat_num)

        self.g_optimizer = torch.optim.Adam(self.G.parameters(), self.g_lr, [self.beta1, self.beta2])
        self.d_optimizer = torch.optim.Adam(self.D.parameters(), self.d_lr, [self.beta1, self.beta2])
        self.print_network(self.G, 'G')
        self.print_network(self.D, 'D')
            
        self.G.to(self.device)
        self.D.to(self.device)

    def print_network(self, model, name):
        """Print out the network information."""
        num_params = 0
        for p in model.parameters():
            num_params += p.numel()
        print(model)
        print(name)
        print("The number of parameters: {}".format(num_params))

    def restore_model(self, resume_iters):
        """Restore the trained generator and discriminator."""
        print('Loading the trained models from step {}...'.format(resume_iters))
        G_path = os.path.join(self.model_save_dir, '{}-G.ckpt'.format(resume_iters))
        D_path = os.path.join(self.model_save_dir, '{}-D.ckpt'.format(resume_iters))
        self.G.load_state_dict(torch.load(G_path, map_location=lambda storage, loc: storage))
        self.D.load_state_dict(torch.load(D_path, map_location=lambda storage, loc: storage))

    def build_tensorboard(self):
        """Build a tensorboard logger."""
        self.logger = Logger(self.log_dir)

    def update_lr(self, g_lr, d_lr):
        """Decay learning rates of the generator and discriminator."""
        for param_group in self.g_optimizer.param_groups:
            param_group['lr'] = g_lr
        for param_group in self.d_optimizer.param_groups:
            param_group['lr'] = d_lr

    def reset_grad(self):
        """Reset the gradient buffers."""
        self.g_optimizer.zero_grad()
        self.d_optimizer.zero_grad()

    def denorm(self, x):
        """Convert the range from [-1, 1] to [0, 1]."""
        out = (x + 1) / 2
        return out.clamp_(0, 1)

    def gradient_penalty(self, y, x):
        """Compute gradient penalty: (L2_norm(dy/dx) - 1)**2."""
        weight = torch.ones(y.size()).to(self.device)
        dydx = torch.autograd.grad(outputs=y,
                                   inputs=x,
                                   grad_outputs=weight,
                                   retain_graph=True,
                                   create_graph=True,
                                   only_inputs=True)[0]

        dydx = dydx.view(dydx.size(0), -1)
        dydx_l2norm = torch.sqrt(torch.sum(dydx**2, dim=1))
        return torch.mean((dydx_l2norm-1)**2)

    def label2onehot(self, labels, dim):
        """Convert label indices to one-hot vectors."""
        batch_size = labels.size(0)
        out = torch.zeros(batch_size, dim)
        out[np.arange(batch_size), labels.long()] = 1
        return out

    def create_labels(self, c_org, c_dim=5, dataset='CelebA', selected_attrs=None):
        """Generate target domain labels for debugging and testing."""
        # Get hair color indices.
        if dataset == 'CelebA':
            hair_color_indices = []
            for i, attr_name in enumerate(selected_attrs):
                if attr_name in ['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Gray_Hair']:
                    hair_color_indices.append(i)

        c_trg_list = []
        for i in range(c_dim):
            if dataset == 'CelebA':
                c_trg = c_org.clone()
                if i in hair_color_indices:  # Set one hair color to 1 and the rest to 0.
                    c_trg[:, i] = 1
                    for j in hair_color_indices:
                        if j != i:
                            c_trg[:, j] = 0
                else:
                    c_trg[:, i] = (c_trg[:, i] == 0)  # Reverse attribute value.
            elif dataset == 'RaFD':
                c_trg = self.label2onehot(torch.ones(c_org.size(0))*i, c_dim)

            c_trg_list.append(c_trg.to(self.device))
        return c_trg_list

    def classification_loss(self, logit, target, dataset='CelebA'):
        """Compute binary or softmax cross entropy loss."""
        if dataset == 'CelebA':
            return F.binary_cross_entropy_with_logits(logit, target, size_average=False) / logit.size(0)
        elif dataset == 'RaFD':
            return F.cross_entropy(logit, target)

    def train(self):
        """Train StarGAN within a single dataset."""
        # Set data loader.
        if self.dataset == 'CelebA':
            data_loader = self.celeba_loader
        elif self.dataset == 'RaFD':
            data_loader = self.rafd_loader

        # Fetch fixed inputs for debugging.
        data_iter = iter(data_loader)
        x_fixed, c_org = next(data_iter)
        x_fixed = x_fixed.to(self.device)
        c_fixed_list = self.create_labels(c_org, self.c_dim, self.dataset, self.selected_attrs)

        # Learning rate cache for decaying.
        g_lr = self.g_lr
        d_lr = self.d_lr

        # Start training from scratch or resume training.
        start_iters = 0
        if self.resume_iters:
            start_iters = self.resume_iters
            self.restore_model(self.resume_iters)

        # Start training.
        print('Start training...')
        start_time = time.time()
        for i in range(start_iters, self.num_iters):

            # =================================================================================== #
            #                             1. Preprocess input data                                #
            # =================================================================================== #

            # Fetch real images and labels.
            try:
                x_real, label_org = next(data_iter)
            except:
                data_iter = iter(data_loader)
                x_real, label_org = next(data_iter)

            # Generate target domain labels randomly.
            rand_idx = torch.randperm(label_org.size(0))
            label_trg = label_org[rand_idx]

            if self.dataset == 'CelebA':
                c_org = label_org.clone()
                c_trg = label_trg.clone()
            elif self.dataset == 'RaFD':
                c_org = self.label2onehot(label_org, self.c_dim)
                c_trg = self.label2onehot(label_trg, self.c_dim)

            x_real = x_real.to(self.device)           # Input images.
            c_org = c_org.to(self.device)             # Original domain labels.
            c_trg = c_trg.to(self.device)             # Target domain labels.
            label_org = label_org.to(self.device)     # Labels for computing classification loss.
            label_trg = label_trg.to(self.device)     # Labels for computing classification loss.

            # =================================================================================== #
            #                             2. Train the discriminator                              #
            # =================================================================================== #

            # Compute loss with real images.
            out_src, out_cls = self.D(x_real)
            d_loss_real = - torch.mean(out_src)
            d_loss_cls = self.classification_loss(out_cls, label_org, self.dataset)

            # Compute loss with fake images.
            x_fake = self.G(x_real, c_trg)
            out_src, out_cls = self.D(x_fake.detach())
            d_loss_fake = torch.mean(out_src)

            # Compute loss for gradient penalty.
            alpha = torch.rand(x_real.size(0), 1, 1, 1).to(self.device)
            x_hat = (alpha * x_real.data + (1 - alpha) * x_fake.data).requires_grad_(True)
            out_src, _ = self.D(x_hat)
            d_loss_gp = self.gradient_penalty(out_src, x_hat)

            # Backward and optimize.
            d_loss = d_loss_real + d_loss_fake + self.lambda_cls * d_loss_cls + self.lambda_gp * d_loss_gp
            self.reset_grad()
            d_loss.backward()
            self.d_optimizer.step()

            # Logging.
            loss = {}
            loss['D/loss_real'] = d_loss_real.item()
            loss['D/loss_fake'] = d_loss_fake.item()
            loss['D/loss_cls'] = d_loss_cls.item()
            loss['D/loss_gp'] = d_loss_gp.item()
            
            # =================================================================================== #
            #                               3. Train the generator                                #
            # =================================================================================== #
            
            if (i+1) % self.n_critic == 0:
                # Original-to-target domain.
                x_fake = self.G(x_real, c_trg)
                out_src, out_cls = self.D(x_fake)
                g_loss_fake = - torch.mean(out_src)
                g_loss_cls = self.classification_loss(out_cls, label_trg, self.dataset)

                # Target-to-original domain.
                x_reconst = self.G(x_fake, c_org)
                g_loss_rec = torch.mean(torch.abs(x_real - x_reconst))

                # Backward and optimize.
                g_loss = g_loss_fake + self.lambda_rec * g_loss_rec + self.lambda_cls * g_loss_cls
                self.reset_grad()
                g_loss.backward()
                self.g_optimizer.step()

                # Logging.
                loss['G/loss_fake'] = g_loss_fake.item()
                loss['G/loss_rec'] = g_loss_rec.item()
                loss['G/loss_cls'] = g_loss_cls.item()

            # =================================================================================== #
            #                                 4. Miscellaneous                                    #
            # =================================================================================== #

            # Print out training information.
            if (i+1) % self.log_step == 0:
                et = time.time() - start_time
                et = str(datetime.timedelta(seconds=et))[:-7]
                log = "Elapsed [{}], Iteration [{}/{}]".format(et, i+1, self.num_iters)
                for tag, value in loss.items():
                    log += ", {}: {:.4f}".format(tag, value)
                print(log)

                if self.use_tensorboard:
                    for tag, value in loss.items():
                        self.logger.scalar_summary(tag, value, i+1)

            # Translate fixed images for debugging.
            if (i+1) % self.sample_step == 0:
                with torch.no_grad():
                    x_fake_list = [x_fixed]
                    for c_fixed in c_fixed_list:
                        x_fake_list.append(self.G(x_fixed, c_fixed))
                    x_concat = torch.cat(x_fake_list, dim=3)
                    sample_path = os.path.join(self.sample_dir, '{}-images.jpg'.format(i+1))
                    save_image(self.denorm(x_concat.data.cpu()), sample_path, nrow=1, padding=0)
                    print('Saved real and fake images into {}...'.format(sample_path))

            # Save model checkpoints.
            if (i+1) % self.model_save_step == 0:
                G_path = os.path.join(self.model_save_dir, '{}-G.ckpt'.format(i+1))
                D_path = os.path.join(self.model_save_dir, '{}-D.ckpt'.format(i+1))
                torch.save(self.G.state_dict(), G_path)
                torch.save(self.D.state_dict(), D_path)
                print('Saved model checkpoints into {}...'.format(self.model_save_dir))

            # Decay learning rates.
            if (i+1) % self.lr_update_step == 0 and (i+1) > (self.num_iters - self.num_iters_decay):
                g_lr -= (self.g_lr / float(self.num_iters_decay))
                d_lr -= (self.d_lr / float(self.num_iters_decay))
                self.update_lr(g_lr, d_lr)
                print ('Decayed learning rates, g_lr: {}, d_lr: {}.'.format(g_lr, d_lr))

    def train_multi(self):
        """Train StarGAN with multiple datasets."""        
        # Data iterators.
        celeba_iter = iter(self.celeba_loader)
        rafd_iter = iter(self.rafd_loader)

        # Fetch fixed inputs for debugging.
        x_fixed, c_org = next(celeba_iter)
        x_fixed = x_fixed.to(self.device)
        c_celeba_list = self.create_labels(c_org, self.c_dim, 'CelebA', self.selected_attrs)
        c_rafd_list = self.create_labels(c_org, self.c2_dim, 'RaFD')
        zero_celeba = torch.zeros(x_fixed.size(0), self.c_dim).to(self.device)           # Zero vector for CelebA.
        zero_rafd = torch.zeros(x_fixed.size(0), self.c2_dim).to(self.device)             # Zero vector for RaFD.
        mask_celeba = self.label2onehot(torch.zeros(x_fixed.size(0)), 2).to(self.device)  # Mask vector: [1, 0].
        mask_rafd = self.label2onehot(torch.ones(x_fixed.size(0)), 2).to(self.device)     # Mask vector: [0, 1].

        # Learning rate cache for decaying.
        g_lr = self.g_lr
        d_lr = self.d_lr

        # Start training from scratch or resume training.
        start_iters = 0
        if self.resume_iters:
            start_iters = self.resume_iters
            self.restore_model(self.resume_iters)

        # Start training.
        print('Start training...')
        start_time = time.time()
        for i in range(start_iters, self.num_iters):
            for dataset in ['CelebA', 'RaFD']:

                # =================================================================================== #
                #                             1. Preprocess input data                                #
                # =================================================================================== #
                
                # Fetch real images and labels.
                data_iter = celeba_iter if dataset == 'CelebA' else rafd_iter
                
                try:
                    x_real, label_org = next(data_iter)
                except:
                    if dataset == 'CelebA':
                        celeba_iter = iter(self.celeba_loader)
                        x_real, label_org = next(celeba_iter)
                    elif dataset == 'RaFD':
                        rafd_iter = iter(self.rafd_loader)
                        x_real, label_org = next(rafd_iter)

                # Generate target domain labels randomly.
                rand_idx = torch.randperm(label_org.size(0))
                label_trg = label_org[rand_idx]

                if dataset == 'CelebA':
                    c_org = label_org.clone()
                    c_trg = label_trg.clone()
                    zero = torch.zeros(x_real.size(0), self.c2_dim)
                    mask = self.label2onehot(torch.zeros(x_real.size(0)), 2)
                    c_org = torch.cat([c_org, zero, mask], dim=1)
                    c_trg = torch.cat([c_trg, zero, mask], dim=1)
                elif dataset == 'RaFD':
                    c_org = self.label2onehot(label_org, self.c2_dim)
                    c_trg = self.label2onehot(label_trg, self.c2_dim)
                    zero = torch.zeros(x_real.size(0), self.c_dim)
                    mask = self.label2onehot(torch.ones(x_real.size(0)), 2)
                    c_org = torch.cat([zero, c_org, mask], dim=1)
                    c_trg = torch.cat([zero, c_trg, mask], dim=1)

                x_real = x_real.to(self.device)             # Input images.
                c_org = c_org.to(self.device)               # Original domain labels.
                c_trg = c_trg.to(self.device)               # Target domain labels.
                label_org = label_org.to(self.device)       # Labels for computing classification loss.
                label_trg = label_trg.to(self.device)       # Labels for computing classification loss.

                # =================================================================================== #
                #                             2. Train the discriminator                              #
                # =================================================================================== #

                # Compute loss with real images.
                out_src, out_cls = self.D(x_real)
                out_cls = out_cls[:, :self.c_dim] if dataset == 'CelebA' else out_cls[:, self.c_dim:]
                d_loss_real = - torch.mean(out_src)
                d_loss_cls = self.classification_loss(out_cls, label_org, dataset)

                # Compute loss with fake images.
                x_fake = self.G(x_real, c_trg)
                out_src, _ = self.D(x_fake.detach())
                d_loss_fake = torch.mean(out_src)

                # Compute loss for gradient penalty.
                alpha = torch.rand(x_real.size(0), 1, 1, 1).to(self.device)
                x_hat = (alpha * x_real.data + (1 - alpha) * x_fake.data).requires_grad_(True)
                out_src, _ = self.D(x_hat)
                d_loss_gp = self.gradient_penalty(out_src, x_hat)

                # Backward and optimize.
                d_loss = d_loss_real + d_loss_fake + self.lambda_cls * d_loss_cls + self.lambda_gp * d_loss_gp
                self.reset_grad()
                d_loss.backward()
                self.d_optimizer.step()

                # Logging.
                loss = {}
                loss['D/loss_real'] = d_loss_real.item()
                loss['D/loss_fake'] = d_loss_fake.item()
                loss['D/loss_cls'] = d_loss_cls.item()
                loss['D/loss_gp'] = d_loss_gp.item()
            
                # =================================================================================== #
                #                               3. Train the generator                                #
                # =================================================================================== #

                if (i+1) % self.n_critic == 0:
                    # Original-to-target domain.
                    x_fake = self.G(x_real, c_trg)
                    out_src, out_cls = self.D(x_fake)
                    out_cls = out_cls[:, :self.c_dim] if dataset == 'CelebA' else out_cls[:, self.c_dim:]
                    g_loss_fake = - torch.mean(out_src)
                    g_loss_cls = self.classification_loss(out_cls, label_trg, dataset)

                    # Target-to-original domain.
                    x_reconst = self.G(x_fake, c_org)
                    g_loss_rec = torch.mean(torch.abs(x_real - x_reconst))

                    # Backward and optimize.
                    g_loss = g_loss_fake + self.lambda_rec * g_loss_rec + self.lambda_cls * g_loss_cls
                    self.reset_grad()
                    g_loss.backward()
                    self.g_optimizer.step()

                    # Logging.
                    loss['G/loss_fake'] = g_loss_fake.item()
                    loss['G/loss_rec'] = g_loss_rec.item()
                    loss['G/loss_cls'] = g_loss_cls.item()

                # =================================================================================== #
                #                                 4. Miscellaneous                                    #
                # =================================================================================== #

                # Print out training info.
                if (i+1) % self.log_step == 0:
                    et = time.time() - start_time
                    et = str(datetime.timedelta(seconds=et))[:-7]
                    log = "Elapsed [{}], Iteration [{}/{}], Dataset [{}]".format(et, i+1, self.num_iters, dataset)
                    for tag, value in loss.items():
                        log += ", {}: {:.4f}".format(tag, value)
                    print(log)

                    if self.use_tensorboard:
                        for tag, value in loss.items():
                            self.logger.scalar_summary(tag, value, i+1)

            # Translate fixed images for debugging.
            if (i+1) % self.sample_step == 0:
                with torch.no_grad():
                    x_fake_list = [x_fixed]
                    for c_fixed in c_celeba_list:
                        c_trg = torch.cat([c_fixed, zero_rafd, mask_celeba], dim=1)
                        x_fake_list.append(self.G(x_fixed, c_trg))
                    for c_fixed in c_rafd_list:
                        c_trg = torch.cat([zero_celeba, c_fixed, mask_rafd], dim=1)
                        x_fake_list.append(self.G(x_fixed, c_trg))
                    x_concat = torch.cat(x_fake_list, dim=3)
                    sample_path = os.path.join(self.sample_dir, '{}-images.jpg'.format(i+1))
                    save_image(self.denorm(x_concat.data.cpu()), sample_path, nrow=1, padding=0)
                    print('Saved real and fake images into {}...'.format(sample_path))

            # Save model checkpoints.
            if (i+1) % self.model_save_step == 0:
                G_path = os.path.join(self.model_save_dir, '{}-G.ckpt'.format(i+1))
                D_path = os.path.join(self.model_save_dir, '{}-D.ckpt'.format(i+1))
                torch.save(self.G.state_dict(), G_path)
                torch.save(self.D.state_dict(), D_path)
                print('Saved model checkpoints into {}...'.format(self.model_save_dir))

            # Decay learning rates.
            if (i+1) % self.lr_update_step == 0 and (i+1) > (self.num_iters - self.num_iters_decay):
                g_lr -= (self.g_lr / float(self.num_iters_decay))
                d_lr -= (self.d_lr / float(self.num_iters_decay))
                self.update_lr(g_lr, d_lr)
                print ('Decayed learning rates, g_lr: {}, d_lr: {}.'.format(g_lr, d_lr))

    def test(self):
        """Translate images using StarGAN trained on a single dataset."""
        # Load the trained generator.
        self.restore_model(self.test_iters)
        
        # Set data loader.
        if self.dataset == 'CelebA':
            data_loader = self.celeba_loader
        elif self.dataset == 'RaFD':
            data_loader = self.rafd_loader
        
        with torch.no_grad():
            for i, (x_real, c_org) in enumerate(data_loader):

                # Prepare input images and target domain labels.
                x_real = x_real.to(self.device)
                c_trg_list = self.create_labels(c_org, self.c_dim, self.dataset, self.selected_attrs)

                # Translate images.
                x_fake_list = [x_real]
                for c_trg in c_trg_list:
                    x_fake_list.append(self.G(x_real, c_trg))

                # Save the translated images.
                x_concat = torch.cat(x_fake_list, dim=3)
                result_path = os.path.join(self.result_dir, '{}-images.jpg'.format(i+1))
                save_image(self.denorm(x_concat.data.cpu()), result_path, nrow=1, padding=0)
                print('Saved real and fake images into {}...'.format(result_path))

    def test_multi(self):
        """Translate images using StarGAN trained on multiple datasets."""
        # Load the trained generator.
        self.restore_model(self.test_iters)
        
        with torch.no_grad():
            for i, (x_real, c_org) in enumerate(self.celeba_loader):

                # Prepare input images and target domain labels.
                x_real = x_real.to(self.device)
                c_celeba_list = self.create_labels(c_org, self.c_dim, 'CelebA', self.selected_attrs)
                c_rafd_list = self.create_labels(c_org, self.c2_dim, 'RaFD')
                zero_celeba = torch.zeros(x_real.size(0), self.c_dim).to(self.device)            # Zero vector for CelebA.
                zero_rafd = torch.zeros(x_real.size(0), self.c2_dim).to(self.device)             # Zero vector for RaFD.
                mask_celeba = self.label2onehot(torch.zeros(x_real.size(0)), 2).to(self.device)  # Mask vector: [1, 0].
                mask_rafd = self.label2onehot(torch.ones(x_real.size(0)), 2).to(self.device)     # Mask vector: [0, 1].

                # Translate images.
                x_fake_list = [x_real]
                for c_celeba in c_celeba_list:
                    c_trg = torch.cat([c_celeba, zero_rafd, mask_celeba], dim=1)
                    x_fake_list.append(self.G(x_real, c_trg))
                for c_rafd in c_rafd_list:
                    c_trg = torch.cat([zero_celeba, c_rafd, mask_rafd], dim=1)
                    x_fake_list.append(self.G(x_real, c_trg))

                # Save the translated images.
                x_concat = torch.cat(x_fake_list, dim=3)
                result_path = os.path.join(self.result_dir, '{}-images.jpg'.format(i+1))
                save_image(self.denorm(x_concat.data.cpu()), result_path, nrow=1, padding=0)
                print('Saved real and fake images into {}...'.format(result_path))

# %% [markdown]
# ## Testing and saving

# %% [markdown]
# ### Runtime functions

# %%
def main(config):
    # For fast training.
    cudnn.benchmark = True

    # Create directories if not exist.
    if not os.path.exists(config.log_dir):
        os.makedirs(config.log_dir)
    if not os.path.exists(config.model_save_dir):
        os.makedirs(config.model_save_dir)
    if not os.path.exists(config.sample_dir):
        os.makedirs(config.sample_dir)
    if not os.path.exists(config.result_dir):
        os.makedirs(config.result_dir)

    # Data loader.
    celeba_loader = None
    rafd_loader = None

    if config.dataset in ['CelebA', 'Both']:
        celeba_loader = get_loader(config.celeba_image_dir, config.attr_path, config.selected_attrs,
                                   config.celeba_crop_size, config.image_size, config.batch_size,
                                   'CelebA', config.mode, config.num_workers)
    if config.dataset in ['RaFD', 'Both']:
        rafd_loader = get_loader(config.rafd_image_dir, None, None,
                                config.rafd_crop_size, config.image_size, config.batch_size,
                                'RaFD', config.mode, config.num_workers)
            
    # Solver for training and testing StarGAN.
    solver = Solver(celeba_loader, rafd_loader, config)

    if config.mode == 'train':
        if config.dataset in ['CelebA', 'RaFD']:
            solver.train()
        elif config.dataset in ['Both']:
            solver.train_multi()
    elif config.mode == 'test':
        if config.dataset in ['CelebA', 'RaFD']:
            solver.test()
        elif config.dataset in ['Both']:
            solver.test_multi()

# %% [markdown]
# ### Configuration

# %%
def run(dir='data/RaFD/train', mode='train'):
    parser = argparse.ArgumentParser()

    # Model configuration.
    parser.add_argument('--c_dim', type=int, default=LABEL_DIM, help='dimension of domain labels (1st dataset)')
    parser.add_argument('--c2_dim', type=int, default=8, help='dimension of domain labels (2nd dataset)')
    parser.add_argument('--celeba_crop_size', type=int, default=178, help='crop size for the CelebA dataset')
    parser.add_argument('--rafd_crop_size', type=int, default=CROP_SIZE, help='crop size for the RaFD dataset')
    parser.add_argument('--image_size', type=int, default=IMG_SIZE, help='image resolution')
    parser.add_argument('--g_conv_dim', type=int, default=64, help='number of conv filters in the first layer of G')
    parser.add_argument('--d_conv_dim', type=int, default=64, help='number of conv filters in the first layer of D')
    parser.add_argument('--g_repeat_num', type=int, default=6, help='number of residual blocks in G')
    parser.add_argument('--d_repeat_num', type=int, default=6, help='number of strided conv layers in D')
    parser.add_argument('--lambda_cls', type=float, default=1, help='weight for domain classification loss')
    parser.add_argument('--lambda_rec', type=float, default=10, help='weight for reconstruction loss')
    parser.add_argument('--lambda_gp', type=float, default=10, help='weight for gradient penalty')
    
    # Training configuration.
    parser.add_argument('--dataset', type=str, default='RaFD', choices=['CelebA', 'RaFD', 'Both'])
    parser.add_argument('--batch_size', type=int, default=2, help='mini-batch size')
    parser.add_argument('--num_iters', type=int, default=100000, help='number of total iterations for training D')
    parser.add_argument('--num_iters_decay', type=int, default=50000, help='number of iterations for decaying lr')
    parser.add_argument('--g_lr', type=float, default=0.0001, help='learning rate for G')
    parser.add_argument('--d_lr', type=float, default=0.0001, help='learning rate for D')
    parser.add_argument('--n_critic', type=int, default=5, help='number of D updates per each G update')
    parser.add_argument('--beta1', type=float, default=0.5, help='beta1 for Adam optimizer')
    parser.add_argument('--beta2', type=float, default=0.999, help='beta2 for Adam optimizer')
    parser.add_argument('--resume_iters', type=int, default=None, help='resume training from this step')
    parser.add_argument('--selected_attrs', '--list', nargs='+', help='selected attributes for the CelebA dataset',
                        default=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'])

    # Test configuration.
    parser.add_argument('--test_iters', type=int, default=100000, help='test model from this step')

    # Miscellaneous.
    parser.add_argument('--num_workers', type=int, default=1)
    parser.add_argument('--mode', type=str, default=mode, choices=['train', 'test'])
    parser.add_argument('--use_tensorboard', type=str2bool, default=True)

    # Directories.
    parser.add_argument('--celeba_image_dir', type=str, default='data/celeba/images')
    parser.add_argument('--attr_path', type=str, default='data/celeba/list_attr_celeba.txt')
    parser.add_argument('--rafd_image_dir', type=str, default=dir)
    parser.add_argument('--log_dir', type=str, default='stargan/logs')
    parser.add_argument('--model_save_dir', type=str, default='stargan/models')
    parser.add_argument('--sample_dir', type=str, default='stargan/samples')
    parser.add_argument('--result_dir', type=str, default='stargan/results')

    # Step size.
    parser.add_argument('--log_step', type=int, default=200)
    parser.add_argument('--sample_step', type=int, default=500)
    parser.add_argument('--model_save_step', type=int, default=2000)
    parser.add_argument('--lr_update_step', type=int, default=100)

    config, _ = parser.parse_known_args()
    print(config)
    main(config)

# %% [markdown]
# ### Training

# %%
run(TRAIN_IMG_DIR, 'train')
# Out:
# Namespace(attr_path='data/celeba/list_attr_celeba.txt', batch_size=2, beta1=0.5, beta2=0.999, c2_dim=8, c_dim=5, celeba_crop_size=178, celeba_image_dir='data/celeba/images', d_conv_dim=64, d_lr=0.0001, d_repeat_num=6, dataset='RaFD', g_conv_dim=64, g_lr=0.0001, g_repeat_num=6, image_size=256, lambda_cls=1, lambda_gp=10, lambda_rec=10, log_dir='stargan/logs', log_step=200, lr_update_step=100, mode='train', model_save_dir='stargan/models', model_save_step=2000, n_critic=5, num_iters=100000, num_iters_decay=50000, num_workers=1, rafd_crop_size=256, rafd_image_dir='data/style/train', result_dir='stargan/results', resume_iters=None, sample_dir='stargan/samples', sample_step=500, selected_attrs=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'], test_iters=100000, use_tensorboard=True)
# Generator(
#   (main): Sequential(
#     (0): Conv2d(8, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (19): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (22): Tanh()
#   )
# )
# G
# The number of parameters: 8430528
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (conv1): Conv2d(2048, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 5, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
# D
# The number of parameters: 44884928
# Start training...
# Elapsed [0:00:40], Iteration [200/100000], D/loss_real: -1.0794, D/loss_fake: 0.5770, D/loss_cls: 0.7688, D/loss_gp: 0.1413, G/loss_fake: -1.5092, G/loss_rec: 0.2445, G/loss_cls: 0.7972
# Elapsed [0:01:20], Iteration [400/100000], D/loss_real: 1.9345, D/loss_fake: -2.5408, D/loss_cls: 0.9181, D/loss_gp: 0.0654, G/loss_fake: 3.3736, G/loss_rec: 0.3797, G/loss_cls: 0.9239
# Saved real and fake images into stargan/samples/500-images.jpg...
# Elapsed [0:02:01], Iteration [600/100000], D/loss_real: -0.7720, D/loss_fake: 0.2057, D/loss_cls: 0.3421, D/loss_gp: 0.0001, G/loss_fake: -0.5050, G/loss_rec: 0.3118, G/loss_cls: 0.2710
# Elapsed [0:02:43], Iteration [800/100000], D/loss_real: 0.4018, D/loss_fake: -2.6655, D/loss_cls: 1.8258, D/loss_gp: 0.0291, G/loss_fake: -1.5013, G/loss_rec: 0.4588, G/loss_cls: 1.7626
# Elapsed [0:03:26], Iteration [1000/100000], D/loss_real: -4.6545, D/loss_fake: -1.8442, D/loss_cls: 0.0066, D/loss_gp: 0.0151, G/loss_fake: 1.1205, G/loss_rec: 0.4669, G/loss_cls: 0.0027
# Saved real and fake images into stargan/samples/1000-images.jpg...
# Elapsed [0:04:08], Iteration [1200/100000], D/loss_real: -3.8012, D/loss_fake: 2.0616, D/loss_cls: 0.1403, D/loss_gp: 0.0138, G/loss_fake: -2.6019, G/loss_rec: 0.2989, G/loss_cls: 0.0915
# Elapsed [0:04:50], Iteration [1400/100000], D/loss_real: -5.7811, D/loss_fake: 3.2437, D/loss_cls: 1.9885, D/loss_gp: 0.0415, G/loss_fake: -2.4833, G/loss_rec: 0.2682, G/loss_cls: 3.6378
# Saved real and fake images into stargan/samples/1500-images.jpg...
# Elapsed [0:05:32], Iteration [1600/100000], D/loss_real: -1.5581, D/loss_fake: 1.0549, D/loss_cls: 2.2141, D/loss_gp: 0.0043, G/loss_fake: -0.8313, G/loss_rec: 0.2700, G/loss_cls: 1.2411
# Elapsed [0:06:15], Iteration [1800/100000], D/loss_real: -2.1149, D/loss_fake: -1.8943, D/loss_cls: 0.0817, D/loss_gp: 0.0006, G/loss_fake: 0.7637, G/loss_rec: 0.2954, G/loss_cls: 0.1762
# Elapsed [0:06:57], Iteration [2000/100000], D/loss_real: -2.8208, D/loss_fake: 1.6189, D/loss_cls: 1.1323, D/loss_gp: 0.0067, G/loss_fake: -1.6449, G/loss_rec: 0.1790, G/loss_cls: 1.7298
# Saved real and fake images into stargan/samples/2000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:07:40], Iteration [2200/100000], D/loss_real: 1.1316, D/loss_fake: -3.3467, D/loss_cls: 0.0275, D/loss_gp: 0.0074, G/loss_fake: 2.4424, G/loss_rec: 0.3468, G/loss_cls: 0.0024
# Elapsed [0:08:22], Iteration [2400/100000], D/loss_real: -9.3513, D/loss_fake: 0.5614, D/loss_cls: 1.1712, D/loss_gp: 0.1615, G/loss_fake: 1.2889, G/loss_rec: 0.3036, G/loss_cls: 0.0154
# Saved real and fake images into stargan/samples/2500-images.jpg...
# Elapsed [0:09:04], Iteration [2600/100000], D/loss_real: 1.7988, D/loss_fake: -3.6602, D/loss_cls: 0.1251, D/loss_gp: 0.0322, G/loss_fake: 4.7852, G/loss_rec: 0.3380, G/loss_cls: 0.0021
# Elapsed [0:09:47], Iteration [2800/100000], D/loss_real: -2.5682, D/loss_fake: -1.0717, D/loss_cls: 0.1762, D/loss_gp: 0.1751, G/loss_fake: 1.6160, G/loss_rec: 0.2948, G/loss_cls: 0.0254
# Elapsed [0:10:29], Iteration [3000/100000], D/loss_real: -1.8493, D/loss_fake: 1.1631, D/loss_cls: 0.5630, D/loss_gp: 0.0091, G/loss_fake: 0.0285, G/loss_rec: 0.3564, G/loss_cls: 0.3159
# Saved real and fake images into stargan/samples/3000-images.jpg...
# Elapsed [0:11:11], Iteration [3200/100000], D/loss_real: 3.6464, D/loss_fake: -1.3722, D/loss_cls: 0.0876, D/loss_gp: 0.0251, G/loss_fake: 3.3781, G/loss_rec: 0.4076, G/loss_cls: 0.0536
# Elapsed [0:11:53], Iteration [3400/100000], D/loss_real: -4.3125, D/loss_fake: 0.7870, D/loss_cls: 0.8097, D/loss_gp: 0.0011, G/loss_fake: -0.2918, G/loss_rec: 0.2669, G/loss_cls: 1.4425
# Saved real and fake images into stargan/samples/3500-images.jpg...
# Elapsed [0:12:36], Iteration [3600/100000], D/loss_real: -10.1014, D/loss_fake: 4.3169, D/loss_cls: 0.3281, D/loss_gp: 0.0327, G/loss_fake: -3.3177, G/loss_rec: 0.3261, G/loss_cls: 0.3985
# Elapsed [0:13:18], Iteration [3800/100000], D/loss_real: -1.9350, D/loss_fake: 2.0699, D/loss_cls: 0.0071, D/loss_gp: 0.0020, G/loss_fake: -0.8652, G/loss_rec: 0.2600, G/loss_cls: 0.0022
# Elapsed [0:14:00], Iteration [4000/100000], D/loss_real: -4.2138, D/loss_fake: 0.6398, D/loss_cls: 0.0176, D/loss_gp: 0.0027, G/loss_fake: 2.9072, G/loss_rec: 0.4824, G/loss_cls: 0.0093
# Saved real and fake images into stargan/samples/4000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:14:43], Iteration [4200/100000], D/loss_real: 0.2691, D/loss_fake: -1.4561, D/loss_cls: 0.0014, D/loss_gp: 0.0079, G/loss_fake: 0.3465, G/loss_rec: 0.3037, G/loss_cls: 0.0041
# Elapsed [0:15:25], Iteration [4400/100000], D/loss_real: -1.5349, D/loss_fake: -2.0364, D/loss_cls: 0.3342, D/loss_gp: 0.0080, G/loss_fake: 2.6515, G/loss_rec: 0.3294, G/loss_cls: 0.1116
# Saved real and fake images into stargan/samples/4500-images.jpg...
# Elapsed [0:16:08], Iteration [4600/100000], D/loss_real: -6.2028, D/loss_fake: 6.1684, D/loss_cls: 0.0284, D/loss_gp: 0.0421, G/loss_fake: -5.2520, G/loss_rec: 0.2772, G/loss_cls: 0.0211
# Elapsed [0:16:50], Iteration [4800/100000], D/loss_real: -9.3184, D/loss_fake: 6.8262, D/loss_cls: 0.3532, D/loss_gp: 0.0119, G/loss_fake: -6.9116, G/loss_rec: 0.3258, G/loss_cls: 0.4830
# Elapsed [0:17:32], Iteration [5000/100000], D/loss_real: -6.5699, D/loss_fake: 2.9562, D/loss_cls: 0.6230, D/loss_gp: 0.0423, G/loss_fake: -3.4829, G/loss_rec: 0.2889, G/loss_cls: 0.3840
# Saved real and fake images into stargan/samples/5000-images.jpg...
# Elapsed [0:18:14], Iteration [5200/100000], D/loss_real: -2.8157, D/loss_fake: -3.6017, D/loss_cls: 1.1925, D/loss_gp: 0.1102, G/loss_fake: 0.6343, G/loss_rec: 0.3931, G/loss_cls: 0.1234
# Elapsed [0:18:56], Iteration [5400/100000], D/loss_real: -7.7464, D/loss_fake: 6.6542, D/loss_cls: 2.5362, D/loss_gp: 0.0108, G/loss_fake: -7.5127, G/loss_rec: 0.3235, G/loss_cls: 2.2782
# Saved real and fake images into stargan/samples/5500-images.jpg...
# Elapsed [0:19:39], Iteration [5600/100000], D/loss_real: 0.4661, D/loss_fake: -4.7388, D/loss_cls: 0.1210, D/loss_gp: 0.0919, G/loss_fake: 6.5397, G/loss_rec: 0.3472, G/loss_cls: 0.0729
# Elapsed [0:20:21], Iteration [5800/100000], D/loss_real: -1.0674, D/loss_fake: -0.0909, D/loss_cls: 0.0386, D/loss_gp: 0.0067, G/loss_fake: -1.5850, G/loss_rec: 0.2585, G/loss_cls: 0.0400
# Elapsed [0:21:03], Iteration [6000/100000], D/loss_real: -2.2065, D/loss_fake: 0.5015, D/loss_cls: 0.7432, D/loss_gp: 0.0006, G/loss_fake: -0.0721, G/loss_rec: 0.2172, G/loss_cls: 0.7807
# Saved real and fake images into stargan/samples/6000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:21:46], Iteration [6200/100000], D/loss_real: -3.1664, D/loss_fake: 2.4119, D/loss_cls: 0.5568, D/loss_gp: 0.0335, G/loss_fake: -1.5404, G/loss_rec: 0.2502, G/loss_cls: 1.2646
# Elapsed [0:22:29], Iteration [6400/100000], D/loss_real: -7.4264, D/loss_fake: 4.6333, D/loss_cls: 0.3564, D/loss_gp: 0.0200, G/loss_fake: -2.8182, G/loss_rec: 0.3021, G/loss_cls: 0.2062
# Saved real and fake images into stargan/samples/6500-images.jpg...
# Elapsed [0:23:11], Iteration [6600/100000], D/loss_real: -3.3546, D/loss_fake: 2.3415, D/loss_cls: 0.4676, D/loss_gp: 0.0033, G/loss_fake: -2.1907, G/loss_rec: 0.2958, G/loss_cls: 0.5192
# Elapsed [0:23:53], Iteration [6800/100000], D/loss_real: -0.6583, D/loss_fake: -0.3768, D/loss_cls: 2.4275, D/loss_gp: 0.0017, G/loss_fake: -0.1773, G/loss_rec: 0.2223, G/loss_cls: 0.8558
# Elapsed [0:24:35], Iteration [7000/100000], D/loss_real: -8.0419, D/loss_fake: 9.0611, D/loss_cls: 0.3877, D/loss_gp: 0.0028, G/loss_fake: -8.1020, G/loss_rec: 0.2397, G/loss_cls: 0.0722
# Saved real and fake images into stargan/samples/7000-images.jpg...
# Elapsed [0:25:18], Iteration [7200/100000], D/loss_real: -2.2079, D/loss_fake: -0.0137, D/loss_cls: 0.4349, D/loss_gp: 0.0451, G/loss_fake: -0.6776, G/loss_rec: 0.2620, G/loss_cls: 0.1644
# Elapsed [0:26:00], Iteration [7400/100000], D/loss_real: -2.7223, D/loss_fake: -0.2454, D/loss_cls: 0.0336, D/loss_gp: 0.0091, G/loss_fake: 1.1815, G/loss_rec: 0.3214, G/loss_cls: 0.0537
# Saved real and fake images into stargan/samples/7500-images.jpg...
# Elapsed [0:26:42], Iteration [7600/100000], D/loss_real: -5.0154, D/loss_fake: 3.9985, D/loss_cls: 0.3637, D/loss_gp: 0.0053, G/loss_fake: -4.1584, G/loss_rec: 0.2337, G/loss_cls: 0.4426
# Elapsed [0:27:24], Iteration [7800/100000], D/loss_real: -8.3978, D/loss_fake: 4.3073, D/loss_cls: 0.4840, D/loss_gp: 0.0105, G/loss_fake: -3.0684, G/loss_rec: 0.2435, G/loss_cls: 0.1207
# Elapsed [0:28:06], Iteration [8000/100000], D/loss_real: -3.3210, D/loss_fake: 0.3593, D/loss_cls: 0.1036, D/loss_gp: 0.0334, G/loss_fake: 2.2877, G/loss_rec: 0.2228, G/loss_cls: 0.0224
# Saved real and fake images into stargan/samples/8000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:28:49], Iteration [8200/100000], D/loss_real: -7.4902, D/loss_fake: 6.5609, D/loss_cls: 0.8141, D/loss_gp: 0.0039, G/loss_fake: -6.3816, G/loss_rec: 0.2548, G/loss_cls: 0.2213
# Elapsed [0:29:32], Iteration [8400/100000], D/loss_real: -5.6982, D/loss_fake: 4.1266, D/loss_cls: 0.0825, D/loss_gp: 0.0215, G/loss_fake: -3.9324, G/loss_rec: 0.2024, G/loss_cls: 0.0231
# Saved real and fake images into stargan/samples/8500-images.jpg...
# Elapsed [0:30:14], Iteration [8600/100000], D/loss_real: -3.9552, D/loss_fake: 2.2782, D/loss_cls: 0.4495, D/loss_gp: 0.0203, G/loss_fake: -1.1852, G/loss_rec: 0.3205, G/loss_cls: 0.1791
# Elapsed [0:30:56], Iteration [8800/100000], D/loss_real: -2.7558, D/loss_fake: 1.9124, D/loss_cls: 0.1052, D/loss_gp: 0.0084, G/loss_fake: -2.4482, G/loss_rec: 0.2159, G/loss_cls: 1.2820
# Elapsed [0:31:38], Iteration [9000/100000], D/loss_real: -4.4674, D/loss_fake: 0.5959, D/loss_cls: 0.7780, D/loss_gp: 0.0421, G/loss_fake: -0.3574, G/loss_rec: 0.2906, G/loss_cls: 0.1648
# Saved real and fake images into stargan/samples/9000-images.jpg...
# Elapsed [0:32:21], Iteration [9200/100000], D/loss_real: -7.9547, D/loss_fake: 4.6909, D/loss_cls: 0.1999, D/loss_gp: 0.0754, G/loss_fake: -5.0142, G/loss_rec: 0.2165, G/loss_cls: 0.1718
# Elapsed [0:33:03], Iteration [9400/100000], D/loss_real: -6.4332, D/loss_fake: 3.8923, D/loss_cls: 0.8747, D/loss_gp: 0.0037, G/loss_fake: -3.2812, G/loss_rec: 0.2219, G/loss_cls: 0.6456
# Saved real and fake images into stargan/samples/9500-images.jpg...
# Elapsed [0:33:45], Iteration [9600/100000], D/loss_real: -6.9416, D/loss_fake: 3.1033, D/loss_cls: 0.8556, D/loss_gp: 0.0043, G/loss_fake: -3.2337, G/loss_rec: 0.2630, G/loss_cls: 0.0490
# Elapsed [0:34:27], Iteration [9800/100000], D/loss_real: -1.7023, D/loss_fake: 1.0220, D/loss_cls: 0.2269, D/loss_gp: 0.0050, G/loss_fake: -0.2026, G/loss_rec: 0.2362, G/loss_cls: 0.1955
# Elapsed [0:35:10], Iteration [10000/100000], D/loss_real: -0.9301, D/loss_fake: 0.5689, D/loss_cls: 0.0132, D/loss_gp: 0.0111, G/loss_fake: -1.6674, G/loss_rec: 0.2776, G/loss_cls: 0.0794
# Saved real and fake images into stargan/samples/10000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:35:53], Iteration [10200/100000], D/loss_real: -3.0796, D/loss_fake: 0.0828, D/loss_cls: 0.1159, D/loss_gp: 0.0629, G/loss_fake: 0.6675, G/loss_rec: 0.3295, G/loss_cls: 0.0224
# Elapsed [0:36:35], Iteration [10400/100000], D/loss_real: -3.6398, D/loss_fake: 1.7460, D/loss_cls: 0.3846, D/loss_gp: 0.0025, G/loss_fake: -1.7073, G/loss_rec: 0.2242, G/loss_cls: 0.0816
# Saved real and fake images into stargan/samples/10500-images.jpg...
# Elapsed [0:37:17], Iteration [10600/100000], D/loss_real: -1.4634, D/loss_fake: -0.5538, D/loss_cls: 0.8094, D/loss_gp: 0.0569, G/loss_fake: 0.4968, G/loss_rec: 0.2148, G/loss_cls: 1.3843
# Elapsed [0:38:00], Iteration [10800/100000], D/loss_real: -3.9992, D/loss_fake: 2.6887, D/loss_cls: 0.1940, D/loss_gp: 0.0022, G/loss_fake: -2.3859, G/loss_rec: 0.2610, G/loss_cls: 0.1364
# Elapsed [0:38:42], Iteration [11000/100000], D/loss_real: -2.8778, D/loss_fake: 1.2332, D/loss_cls: 1.5276, D/loss_gp: 0.0160, G/loss_fake: -0.2881, G/loss_rec: 0.2029, G/loss_cls: 4.5414
# Saved real and fake images into stargan/samples/11000-images.jpg...
# Elapsed [0:39:24], Iteration [11200/100000], D/loss_real: 0.1603, D/loss_fake: -2.0609, D/loss_cls: 0.1980, D/loss_gp: 0.0740, G/loss_fake: 1.7618, G/loss_rec: 0.2278, G/loss_cls: 1.1230
# Elapsed [0:40:06], Iteration [11400/100000], D/loss_real: -5.0227, D/loss_fake: 3.8013, D/loss_cls: 0.2144, D/loss_gp: 0.0847, G/loss_fake: -3.6185, G/loss_rec: 0.1786, G/loss_cls: 0.0497
# Saved real and fake images into stargan/samples/11500-images.jpg...
# Elapsed [0:40:49], Iteration [11600/100000], D/loss_real: -6.2954, D/loss_fake: 1.4528, D/loss_cls: 0.4035, D/loss_gp: 0.0147, G/loss_fake: -1.2668, G/loss_rec: 0.3645, G/loss_cls: 0.0733
# Elapsed [0:41:31], Iteration [11800/100000], D/loss_real: -2.5496, D/loss_fake: 1.9302, D/loss_cls: 0.4520, D/loss_gp: 0.0022, G/loss_fake: -1.7069, G/loss_rec: 0.1590, G/loss_cls: 0.2120
# Elapsed [0:42:13], Iteration [12000/100000], D/loss_real: -3.8852, D/loss_fake: 0.4018, D/loss_cls: 0.5633, D/loss_gp: 0.0362, G/loss_fake: 0.0079, G/loss_rec: 0.2583, G/loss_cls: 0.0371
# Saved real and fake images into stargan/samples/12000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:42:56], Iteration [12200/100000], D/loss_real: -3.5001, D/loss_fake: 2.6536, D/loss_cls: 1.0154, D/loss_gp: 0.0003, G/loss_fake: -2.6194, G/loss_rec: 0.2344, G/loss_cls: 2.4098
# Elapsed [0:43:38], Iteration [12400/100000], D/loss_real: -5.9338, D/loss_fake: 2.9743, D/loss_cls: 0.9721, D/loss_gp: 0.0034, G/loss_fake: -2.7939, G/loss_rec: 0.2796, G/loss_cls: 0.1567
# Saved real and fake images into stargan/samples/12500-images.jpg...
# Elapsed [0:44:20], Iteration [12600/100000], D/loss_real: -3.7690, D/loss_fake: 2.4708, D/loss_cls: 0.7606, D/loss_gp: 0.0116, G/loss_fake: -2.6825, G/loss_rec: 0.2425, G/loss_cls: 0.4648
# Elapsed [0:45:02], Iteration [12800/100000], D/loss_real: -2.9048, D/loss_fake: 0.3576, D/loss_cls: 0.8413, D/loss_gp: 0.0097, G/loss_fake: 0.7727, G/loss_rec: 0.3025, G/loss_cls: 1.7342
# Elapsed [0:45:44], Iteration [13000/100000], D/loss_real: -3.1634, D/loss_fake: 2.5135, D/loss_cls: 1.0766, D/loss_gp: 0.0083, G/loss_fake: -2.6244, G/loss_rec: 0.2200, G/loss_cls: 1.9581
# Saved real and fake images into stargan/samples/13000-images.jpg...
# Elapsed [0:46:27], Iteration [13200/100000], D/loss_real: -5.7281, D/loss_fake: 2.8109, D/loss_cls: 0.4782, D/loss_gp: 0.0275, G/loss_fake: -2.9398, G/loss_rec: 0.3090, G/loss_cls: 1.0866
# Elapsed [0:47:09], Iteration [13400/100000], D/loss_real: -5.0804, D/loss_fake: 3.2874, D/loss_cls: 1.0503, D/loss_gp: 0.0082, G/loss_fake: -3.6592, G/loss_rec: 0.2930, G/loss_cls: 0.1529
# Saved real and fake images into stargan/samples/13500-images.jpg...
# Elapsed [0:47:52], Iteration [13600/100000], D/loss_real: -2.8005, D/loss_fake: 1.8115, D/loss_cls: 0.0015, D/loss_gp: 0.0004, G/loss_fake: -1.5387, G/loss_rec: 0.2106, G/loss_cls: 0.0010
# Elapsed [0:48:34], Iteration [13800/100000], D/loss_real: -2.7907, D/loss_fake: 2.1012, D/loss_cls: 0.0895, D/loss_gp: 0.0051, G/loss_fake: -1.8792, G/loss_rec: 0.1782, G/loss_cls: 0.0484
# Elapsed [0:49:16], Iteration [14000/100000], D/loss_real: 1.4969, D/loss_fake: -2.3998, D/loss_cls: 2.7943, D/loss_gp: 0.0038, G/loss_fake: -0.3744, G/loss_rec: 0.2206, G/loss_cls: 0.7598
# Saved real and fake images into stargan/samples/14000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:49:59], Iteration [14200/100000], D/loss_real: -4.7588, D/loss_fake: 3.9770, D/loss_cls: 2.6326, D/loss_gp: 0.0340, G/loss_fake: -2.9439, G/loss_rec: 0.3223, G/loss_cls: 1.0537
# Elapsed [0:50:41], Iteration [14400/100000], D/loss_real: -3.9953, D/loss_fake: 2.0897, D/loss_cls: 0.2627, D/loss_gp: 0.0001, G/loss_fake: -2.3336, G/loss_rec: 0.1712, G/loss_cls: 0.1214
# Saved real and fake images into stargan/samples/14500-images.jpg...
# Elapsed [0:51:24], Iteration [14600/100000], D/loss_real: -3.6888, D/loss_fake: 2.1910, D/loss_cls: 0.5317, D/loss_gp: 0.0069, G/loss_fake: -1.6450, G/loss_rec: 0.2707, G/loss_cls: 0.0579
# Elapsed [0:52:06], Iteration [14800/100000], D/loss_real: -3.9692, D/loss_fake: 1.9579, D/loss_cls: 1.1317, D/loss_gp: 0.0057, G/loss_fake: -1.8444, G/loss_rec: 0.3022, G/loss_cls: 1.7633
# Elapsed [0:52:48], Iteration [15000/100000], D/loss_real: -1.2924, D/loss_fake: 1.3007, D/loss_cls: 1.0609, D/loss_gp: 0.0147, G/loss_fake: -0.6206, G/loss_rec: 0.2088, G/loss_cls: 0.2481
# Saved real and fake images into stargan/samples/15000-images.jpg...
# Elapsed [0:53:30], Iteration [15200/100000], D/loss_real: -1.7267, D/loss_fake: 0.8213, D/loss_cls: 0.0130, D/loss_gp: 0.0008, G/loss_fake: -0.5922, G/loss_rec: 0.1651, G/loss_cls: 0.0024
# Elapsed [0:54:12], Iteration [15400/100000], D/loss_real: -3.6422, D/loss_fake: 0.4312, D/loss_cls: 1.0843, D/loss_gp: 0.0428, G/loss_fake: -1.2286, G/loss_rec: 0.2373, G/loss_cls: 0.1250
# Saved real and fake images into stargan/samples/15500-images.jpg...
# Elapsed [0:54:55], Iteration [15600/100000], D/loss_real: -5.8389, D/loss_fake: 3.6989, D/loss_cls: 0.3157, D/loss_gp: 0.0977, G/loss_fake: -3.9659, G/loss_rec: 0.2049, G/loss_cls: 0.1208
# Elapsed [0:55:37], Iteration [15800/100000], D/loss_real: -2.7876, D/loss_fake: 1.7870, D/loss_cls: 0.6936, D/loss_gp: 0.0034, G/loss_fake: -0.8714, G/loss_rec: 0.2248, G/loss_cls: 0.0582
# Elapsed [0:56:19], Iteration [16000/100000], D/loss_real: -1.7822, D/loss_fake: 0.7358, D/loss_cls: 0.1743, D/loss_gp: 0.0008, G/loss_fake: -0.4987, G/loss_rec: 0.1721, G/loss_cls: 0.1067
# Saved real and fake images into stargan/samples/16000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [0:57:02], Iteration [16200/100000], D/loss_real: -3.8235, D/loss_fake: 2.7438, D/loss_cls: 0.8098, D/loss_gp: 0.0421, G/loss_fake: -2.2127, G/loss_rec: 0.2529, G/loss_cls: 1.6490
# Elapsed [0:57:44], Iteration [16400/100000], D/loss_real: -7.8382, D/loss_fake: 5.2154, D/loss_cls: 1.3612, D/loss_gp: 0.0104, G/loss_fake: -4.6145, G/loss_rec: 0.2396, G/loss_cls: 0.3522
# Saved real and fake images into stargan/samples/16500-images.jpg...
# Elapsed [0:58:27], Iteration [16600/100000], D/loss_real: -1.2723, D/loss_fake: -2.1653, D/loss_cls: 0.1455, D/loss_gp: 0.0192, G/loss_fake: 2.5096, G/loss_rec: 0.2311, G/loss_cls: 0.0040
# Elapsed [0:59:09], Iteration [16800/100000], D/loss_real: -2.9419, D/loss_fake: 1.1932, D/loss_cls: 1.3878, D/loss_gp: 0.0521, G/loss_fake: -1.6182, G/loss_rec: 0.1998, G/loss_cls: 0.7579
# Elapsed [0:59:51], Iteration [17000/100000], D/loss_real: -3.4291, D/loss_fake: 0.4213, D/loss_cls: 1.6563, D/loss_gp: 0.0700, G/loss_fake: -0.9189, G/loss_rec: 0.2517, G/loss_cls: 0.7161
# Saved real and fake images into stargan/samples/17000-images.jpg...
# Elapsed [1:00:33], Iteration [17200/100000], D/loss_real: -1.8527, D/loss_fake: 0.5281, D/loss_cls: 1.2536, D/loss_gp: 0.0023, G/loss_fake: -0.7702, G/loss_rec: 0.2015, G/loss_cls: 0.1634
# Elapsed [1:01:15], Iteration [17400/100000], D/loss_real: -3.2109, D/loss_fake: 1.9342, D/loss_cls: 0.8911, D/loss_gp: 0.0007, G/loss_fake: -1.6994, G/loss_rec: 0.2256, G/loss_cls: 1.3102
# Saved real and fake images into stargan/samples/17500-images.jpg...
# Elapsed [1:01:58], Iteration [17600/100000], D/loss_real: -3.9068, D/loss_fake: 1.2857, D/loss_cls: 0.2388, D/loss_gp: 0.1091, G/loss_fake: -2.0175, G/loss_rec: 0.2512, G/loss_cls: 0.0638
# Elapsed [1:02:40], Iteration [17800/100000], D/loss_real: -3.2526, D/loss_fake: 2.3621, D/loss_cls: 1.6120, D/loss_gp: 0.0040, G/loss_fake: -2.0541, G/loss_rec: 0.1835, G/loss_cls: 0.0067
# Elapsed [1:03:22], Iteration [18000/100000], D/loss_real: -6.8744, D/loss_fake: 1.7753, D/loss_cls: 0.0283, D/loss_gp: 0.0150, G/loss_fake: -1.5671, G/loss_rec: 0.2623, G/loss_cls: 0.0004
# Saved real and fake images into stargan/samples/18000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:04:05], Iteration [18200/100000], D/loss_real: -5.1633, D/loss_fake: 2.5796, D/loss_cls: 0.7707, D/loss_gp: 0.0255, G/loss_fake: -2.0933, G/loss_rec: 0.2201, G/loss_cls: 0.3602
# Elapsed [1:04:48], Iteration [18400/100000], D/loss_real: -0.6613, D/loss_fake: -0.2845, D/loss_cls: 0.4417, D/loss_gp: 0.0056, G/loss_fake: 0.6299, G/loss_rec: 0.2011, G/loss_cls: 0.1667
# Saved real and fake images into stargan/samples/18500-images.jpg...
# Elapsed [1:05:30], Iteration [18600/100000], D/loss_real: -1.9044, D/loss_fake: 0.6482, D/loss_cls: 0.0239, D/loss_gp: 0.0007, G/loss_fake: -0.6006, G/loss_rec: 0.1857, G/loss_cls: 0.0175
# Elapsed [1:06:12], Iteration [18800/100000], D/loss_real: -1.9830, D/loss_fake: 1.4263, D/loss_cls: 0.2605, D/loss_gp: 0.0283, G/loss_fake: -1.4785, G/loss_rec: 0.1717, G/loss_cls: 0.0484
# Elapsed [1:06:54], Iteration [19000/100000], D/loss_real: -0.9881, D/loss_fake: -0.5890, D/loss_cls: 0.3176, D/loss_gp: 0.0232, G/loss_fake: 0.6530, G/loss_rec: 0.1730, G/loss_cls: 0.0142
# Saved real and fake images into stargan/samples/19000-images.jpg...
# Elapsed [1:07:37], Iteration [19200/100000], D/loss_real: -3.4156, D/loss_fake: 2.3483, D/loss_cls: 1.5635, D/loss_gp: 0.0165, G/loss_fake: -2.1487, G/loss_rec: 0.1938, G/loss_cls: 0.8938
# Elapsed [1:08:19], Iteration [19400/100000], D/loss_real: -2.1428, D/loss_fake: 0.8539, D/loss_cls: 1.5349, D/loss_gp: 0.0057, G/loss_fake: -0.7521, G/loss_rec: 0.2277, G/loss_cls: 1.1559
# Saved real and fake images into stargan/samples/19500-images.jpg...
# Elapsed [1:09:01], Iteration [19600/100000], D/loss_real: -1.7301, D/loss_fake: -0.2521, D/loss_cls: 1.9771, D/loss_gp: 0.0081, G/loss_fake: 0.3868, G/loss_rec: 0.2303, G/loss_cls: 1.2153
# Elapsed [1:09:43], Iteration [19800/100000], D/loss_real: -4.5809, D/loss_fake: 2.3682, D/loss_cls: 1.2686, D/loss_gp: 0.0397, G/loss_fake: -2.4178, G/loss_rec: 0.2041, G/loss_cls: 0.1680
# Elapsed [1:10:26], Iteration [20000/100000], D/loss_real: -4.0627, D/loss_fake: 1.9829, D/loss_cls: 0.1135, D/loss_gp: 0.0223, G/loss_fake: -1.9004, G/loss_rec: 0.2672, G/loss_cls: 0.6508
# Saved real and fake images into stargan/samples/20000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:11:09], Iteration [20200/100000], D/loss_real: -5.5482, D/loss_fake: 4.8770, D/loss_cls: 4.6910, D/loss_gp: 0.0103, G/loss_fake: -4.7148, G/loss_rec: 0.2599, G/loss_cls: 0.6959
# Elapsed [1:11:51], Iteration [20400/100000], D/loss_real: -6.2757, D/loss_fake: 3.7671, D/loss_cls: 2.2912, D/loss_gp: 0.0355, G/loss_fake: -2.8462, G/loss_rec: 0.2248, G/loss_cls: 1.2182
# Saved real and fake images into stargan/samples/20500-images.jpg...
# Elapsed [1:12:33], Iteration [20600/100000], D/loss_real: 0.4600, D/loss_fake: -2.7540, D/loss_cls: 0.0714, D/loss_gp: 0.1704, G/loss_fake: -0.6288, G/loss_rec: 0.1830, G/loss_cls: 0.0394
# Elapsed [1:13:16], Iteration [20800/100000], D/loss_real: -5.0392, D/loss_fake: 3.5964, D/loss_cls: 0.4384, D/loss_gp: 0.0043, G/loss_fake: -3.2530, G/loss_rec: 0.2031, G/loss_cls: 0.4615
# Elapsed [1:13:58], Iteration [21000/100000], D/loss_real: -3.8187, D/loss_fake: 1.5600, D/loss_cls: 0.5025, D/loss_gp: 0.0080, G/loss_fake: -2.1309, G/loss_rec: 0.3224, G/loss_cls: 1.4954
# Saved real and fake images into stargan/samples/21000-images.jpg...
# Elapsed [1:14:40], Iteration [21200/100000], D/loss_real: -1.6726, D/loss_fake: 1.2789, D/loss_cls: 0.8196, D/loss_gp: 0.0012, G/loss_fake: -0.8323, G/loss_rec: 0.1980, G/loss_cls: 0.0317
# Elapsed [1:15:22], Iteration [21400/100000], D/loss_real: -3.3202, D/loss_fake: 3.3928, D/loss_cls: 0.9815, D/loss_gp: 0.0071, G/loss_fake: -2.7511, G/loss_rec: 0.1751, G/loss_cls: 0.2452
# Saved real and fake images into stargan/samples/21500-images.jpg...
# Elapsed [1:16:05], Iteration [21600/100000], D/loss_real: -4.8666, D/loss_fake: 2.9639, D/loss_cls: 0.0844, D/loss_gp: 0.0357, G/loss_fake: -3.0667, G/loss_rec: 0.3094, G/loss_cls: 1.3544
# Elapsed [1:16:47], Iteration [21800/100000], D/loss_real: -3.2302, D/loss_fake: 0.9798, D/loss_cls: 0.1738, D/loss_gp: 0.0425, G/loss_fake: -0.6953, G/loss_rec: 0.3149, G/loss_cls: 0.0219
# Elapsed [1:17:29], Iteration [22000/100000], D/loss_real: -2.0312, D/loss_fake: 0.2802, D/loss_cls: 0.0110, D/loss_gp: 0.0231, G/loss_fake: 0.0702, G/loss_rec: 0.2020, G/loss_cls: 0.0012
# Saved real and fake images into stargan/samples/22000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:18:12], Iteration [22200/100000], D/loss_real: -3.5197, D/loss_fake: 2.4175, D/loss_cls: 0.6706, D/loss_gp: 0.0048, G/loss_fake: -2.0989, G/loss_rec: 0.3046, G/loss_cls: 0.2707
# Elapsed [1:18:54], Iteration [22400/100000], D/loss_real: -3.2601, D/loss_fake: 0.4861, D/loss_cls: 0.0349, D/loss_gp: 0.0100, G/loss_fake: -0.2082, G/loss_rec: 0.2259, G/loss_cls: 0.9765
# Saved real and fake images into stargan/samples/22500-images.jpg...
# Elapsed [1:19:37], Iteration [22600/100000], D/loss_real: -4.5180, D/loss_fake: 2.0586, D/loss_cls: 0.3504, D/loss_gp: 0.0052, G/loss_fake: -1.7612, G/loss_rec: 0.2792, G/loss_cls: 1.4759
# Elapsed [1:20:19], Iteration [22800/100000], D/loss_real: -4.7444, D/loss_fake: 3.4390, D/loss_cls: 0.0523, D/loss_gp: 0.0115, G/loss_fake: -3.8427, G/loss_rec: 0.2671, G/loss_cls: 0.0578
# Elapsed [1:21:01], Iteration [23000/100000], D/loss_real: -5.7674, D/loss_fake: 3.0134, D/loss_cls: 1.8130, D/loss_gp: 0.1399, G/loss_fake: -3.2095, G/loss_rec: 0.2286, G/loss_cls: 0.1330
# Saved real and fake images into stargan/samples/23000-images.jpg...
# Elapsed [1:21:44], Iteration [23200/100000], D/loss_real: -2.8293, D/loss_fake: 0.8980, D/loss_cls: 0.0546, D/loss_gp: 0.0177, G/loss_fake: -1.0321, G/loss_rec: 0.2049, G/loss_cls: 0.0072
# Elapsed [1:22:26], Iteration [23400/100000], D/loss_real: -3.4266, D/loss_fake: 1.3319, D/loss_cls: 0.0853, D/loss_gp: 0.0006, G/loss_fake: -1.3774, G/loss_rec: 0.2083, G/loss_cls: 0.0044
# Saved real and fake images into stargan/samples/23500-images.jpg...
# Elapsed [1:23:08], Iteration [23600/100000], D/loss_real: -4.2551, D/loss_fake: 3.0313, D/loss_cls: 0.0665, D/loss_gp: 0.0201, G/loss_fake: -2.8878, G/loss_rec: 0.1769, G/loss_cls: 0.0018
# Elapsed [1:23:50], Iteration [23800/100000], D/loss_real: -2.3608, D/loss_fake: -0.4912, D/loss_cls: 1.8507, D/loss_gp: 0.0111, G/loss_fake: 1.0796, G/loss_rec: 0.1842, G/loss_cls: 0.0062
# Elapsed [1:24:32], Iteration [24000/100000], D/loss_real: -0.6773, D/loss_fake: -0.7984, D/loss_cls: 0.8255, D/loss_gp: 0.0047, G/loss_fake: 0.6182, G/loss_rec: 0.2307, G/loss_cls: 0.0290
# Saved real and fake images into stargan/samples/24000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:25:16], Iteration [24200/100000], D/loss_real: -3.7383, D/loss_fake: 2.0373, D/loss_cls: 0.8431, D/loss_gp: 0.0059, G/loss_fake: -2.3194, G/loss_rec: 0.2358, G/loss_cls: 2.2139
# Elapsed [1:25:58], Iteration [24400/100000], D/loss_real: -3.6370, D/loss_fake: 3.7141, D/loss_cls: 0.4437, D/loss_gp: 0.0006, G/loss_fake: -3.2568, G/loss_rec: 0.2756, G/loss_cls: 0.3731
# Saved real and fake images into stargan/samples/24500-images.jpg...
# Elapsed [1:26:40], Iteration [24600/100000], D/loss_real: -4.0866, D/loss_fake: 3.0613, D/loss_cls: 1.0023, D/loss_gp: 0.0297, G/loss_fake: -2.9524, G/loss_rec: 0.2261, G/loss_cls: 0.9194
# Elapsed [1:27:23], Iteration [24800/100000], D/loss_real: -4.0405, D/loss_fake: 1.4042, D/loss_cls: 2.9472, D/loss_gp: 0.0451, G/loss_fake: -2.7152, G/loss_rec: 0.2172, G/loss_cls: 2.1871
# Elapsed [1:28:05], Iteration [25000/100000], D/loss_real: -3.6779, D/loss_fake: 2.4392, D/loss_cls: 1.2297, D/loss_gp: 0.0003, G/loss_fake: -2.2957, G/loss_rec: 0.2014, G/loss_cls: 0.7192
# Saved real and fake images into stargan/samples/25000-images.jpg...
# Elapsed [1:28:47], Iteration [25200/100000], D/loss_real: -2.6985, D/loss_fake: 0.0821, D/loss_cls: 0.0411, D/loss_gp: 0.0069, G/loss_fake: 0.9102, G/loss_rec: 0.3084, G/loss_cls: 0.6676
# Elapsed [1:29:29], Iteration [25400/100000], D/loss_real: -4.4732, D/loss_fake: 2.9574, D/loss_cls: 2.4731, D/loss_gp: 0.0073, G/loss_fake: -1.7507, G/loss_rec: 0.2181, G/loss_cls: 0.0022
# Saved real and fake images into stargan/samples/25500-images.jpg...
# Elapsed [1:30:12], Iteration [25600/100000], D/loss_real: -3.8873, D/loss_fake: 2.6274, D/loss_cls: 0.0293, D/loss_gp: 0.0090, G/loss_fake: -2.8244, G/loss_rec: 0.1749, G/loss_cls: 0.0114
# Elapsed [1:30:54], Iteration [25800/100000], D/loss_real: -3.6874, D/loss_fake: 2.1633, D/loss_cls: 0.0786, D/loss_gp: 0.0344, G/loss_fake: -1.9637, G/loss_rec: 0.1845, G/loss_cls: 2.6136
# Elapsed [1:31:36], Iteration [26000/100000], D/loss_real: -3.1844, D/loss_fake: 1.2845, D/loss_cls: 0.2657, D/loss_gp: 0.0011, G/loss_fake: -0.9674, G/loss_rec: 0.2365, G/loss_cls: 0.0058
# Saved real and fake images into stargan/samples/26000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:32:19], Iteration [26200/100000], D/loss_real: -4.1241, D/loss_fake: 1.9801, D/loss_cls: 0.0231, D/loss_gp: 0.0204, G/loss_fake: -1.3848, G/loss_rec: 0.1819, G/loss_cls: 1.7791
# Elapsed [1:33:01], Iteration [26400/100000], D/loss_real: -6.0747, D/loss_fake: 4.2999, D/loss_cls: 0.0009, D/loss_gp: 0.0053, G/loss_fake: -4.2230, G/loss_rec: 0.2614, G/loss_cls: 0.0002
# Saved real and fake images into stargan/samples/26500-images.jpg...
# Elapsed [1:33:44], Iteration [26600/100000], D/loss_real: -2.7704, D/loss_fake: 1.5950, D/loss_cls: 0.2099, D/loss_gp: 0.0069, G/loss_fake: -1.6969, G/loss_rec: 0.1787, G/loss_cls: 0.0424
# Elapsed [1:34:26], Iteration [26800/100000], D/loss_real: -2.5011, D/loss_fake: 1.0272, D/loss_cls: 1.3605, D/loss_gp: 0.0149, G/loss_fake: -0.7819, G/loss_rec: 0.2024, G/loss_cls: 0.0063
# Elapsed [1:35:08], Iteration [27000/100000], D/loss_real: -2.9589, D/loss_fake: 0.7144, D/loss_cls: 0.0344, D/loss_gp: 0.0239, G/loss_fake: -0.8841, G/loss_rec: 0.2047, G/loss_cls: 0.0328
# Saved real and fake images into stargan/samples/27000-images.jpg...
# Elapsed [1:35:51], Iteration [27200/100000], D/loss_real: -5.3222, D/loss_fake: 3.2899, D/loss_cls: 2.1215, D/loss_gp: 0.0063, G/loss_fake: -2.9089, G/loss_rec: 0.3361, G/loss_cls: 0.0642
# Elapsed [1:36:33], Iteration [27400/100000], D/loss_real: -3.5598, D/loss_fake: 2.4255, D/loss_cls: 0.4304, D/loss_gp: 0.0000, G/loss_fake: -2.2088, G/loss_rec: 0.2544, G/loss_cls: 2.5568
# Saved real and fake images into stargan/samples/27500-images.jpg...
# Elapsed [1:37:15], Iteration [27600/100000], D/loss_real: -2.7841, D/loss_fake: 2.2390, D/loss_cls: 1.4591, D/loss_gp: 0.0062, G/loss_fake: -1.5859, G/loss_rec: 0.1994, G/loss_cls: 0.3702
# Elapsed [1:37:57], Iteration [27800/100000], D/loss_real: -0.8126, D/loss_fake: -0.3299, D/loss_cls: 0.5309, D/loss_gp: 0.0005, G/loss_fake: 1.0982, G/loss_rec: 0.1734, G/loss_cls: 0.0031
# Elapsed [1:38:39], Iteration [28000/100000], D/loss_real: -6.0967, D/loss_fake: 4.3831, D/loss_cls: 0.0255, D/loss_gp: 0.0680, G/loss_fake: -3.0003, G/loss_rec: 0.2234, G/loss_cls: 0.0321
# Saved real and fake images into stargan/samples/28000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:39:23], Iteration [28200/100000], D/loss_real: -2.9154, D/loss_fake: 1.6275, D/loss_cls: 0.7153, D/loss_gp: 0.0072, G/loss_fake: -1.5277, G/loss_rec: 0.1676, G/loss_cls: 0.3363
# Elapsed [1:40:05], Iteration [28400/100000], D/loss_real: -2.0402, D/loss_fake: 1.6812, D/loss_cls: 0.3035, D/loss_gp: 0.0044, G/loss_fake: -1.1642, G/loss_rec: 0.1728, G/loss_cls: 0.0914
# Saved real and fake images into stargan/samples/28500-images.jpg...
# Elapsed [1:40:47], Iteration [28600/100000], D/loss_real: -1.1025, D/loss_fake: 0.7460, D/loss_cls: 0.0577, D/loss_gp: 0.0128, G/loss_fake: -0.5149, G/loss_rec: 0.2281, G/loss_cls: 0.0098
# Elapsed [1:41:30], Iteration [28800/100000], D/loss_real: -3.3410, D/loss_fake: 2.6215, D/loss_cls: 0.0136, D/loss_gp: 0.0062, G/loss_fake: -2.7724, G/loss_rec: 0.2169, G/loss_cls: 0.0037
# Elapsed [1:42:12], Iteration [29000/100000], D/loss_real: -1.7077, D/loss_fake: 0.8798, D/loss_cls: 2.4476, D/loss_gp: 0.0020, G/loss_fake: -0.7629, G/loss_rec: 0.2679, G/loss_cls: 0.0454
# Saved real and fake images into stargan/samples/29000-images.jpg...
# Elapsed [1:42:54], Iteration [29200/100000], D/loss_real: -2.6872, D/loss_fake: 2.1246, D/loss_cls: 1.2385, D/loss_gp: 0.0070, G/loss_fake: -1.8621, G/loss_rec: 0.2034, G/loss_cls: 0.3457
# Elapsed [1:43:36], Iteration [29400/100000], D/loss_real: -3.5682, D/loss_fake: 2.9468, D/loss_cls: 0.1352, D/loss_gp: 0.0076, G/loss_fake: -2.7272, G/loss_rec: 0.1583, G/loss_cls: 0.0225
# Saved real and fake images into stargan/samples/29500-images.jpg...
# Elapsed [1:44:19], Iteration [29600/100000], D/loss_real: -2.2904, D/loss_fake: -0.4190, D/loss_cls: 2.3058, D/loss_gp: 0.0124, G/loss_fake: 0.4644, G/loss_rec: 0.3246, G/loss_cls: 0.1609
# Elapsed [1:45:01], Iteration [29800/100000], D/loss_real: -1.8483, D/loss_fake: 0.8182, D/loss_cls: 1.8165, D/loss_gp: 0.0006, G/loss_fake: 0.0159, G/loss_rec: 0.3225, G/loss_cls: 0.7422
# Elapsed [1:45:43], Iteration [30000/100000], D/loss_real: -5.0921, D/loss_fake: 3.3562, D/loss_cls: 1.4975, D/loss_gp: 0.0216, G/loss_fake: -1.5582, G/loss_rec: 0.2346, G/loss_cls: 0.0421
# Saved real and fake images into stargan/samples/30000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:46:26], Iteration [30200/100000], D/loss_real: -3.7983, D/loss_fake: 2.3734, D/loss_cls: 0.0594, D/loss_gp: 0.0139, G/loss_fake: -2.5344, G/loss_rec: 0.1554, G/loss_cls: 0.0211
# Elapsed [1:47:08], Iteration [30400/100000], D/loss_real: -3.1842, D/loss_fake: 1.7399, D/loss_cls: 0.0149, D/loss_gp: 0.0032, G/loss_fake: -1.3660, G/loss_rec: 0.1876, G/loss_cls: 0.0337
# Saved real and fake images into stargan/samples/30500-images.jpg...
# Elapsed [1:47:51], Iteration [30600/100000], D/loss_real: -1.7120, D/loss_fake: 1.0495, D/loss_cls: 0.0050, D/loss_gp: 0.0017, G/loss_fake: -0.4456, G/loss_rec: 0.1784, G/loss_cls: 0.0015
# Elapsed [1:48:33], Iteration [30800/100000], D/loss_real: -4.5276, D/loss_fake: 1.2085, D/loss_cls: 0.2700, D/loss_gp: 0.0141, G/loss_fake: -1.4202, G/loss_rec: 0.2643, G/loss_cls: 0.0001
# Elapsed [1:49:15], Iteration [31000/100000], D/loss_real: 3.8301, D/loss_fake: -6.1101, D/loss_cls: 0.0021, D/loss_gp: 0.0431, G/loss_fake: 4.0153, G/loss_rec: 0.2231, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/31000-images.jpg...
# Elapsed [1:49:58], Iteration [31200/100000], D/loss_real: -1.4777, D/loss_fake: 0.8033, D/loss_cls: 0.7888, D/loss_gp: 0.0074, G/loss_fake: -0.4069, G/loss_rec: 0.1786, G/loss_cls: 0.0067
# Elapsed [1:50:40], Iteration [31400/100000], D/loss_real: -7.4688, D/loss_fake: 5.3835, D/loss_cls: 0.0000, D/loss_gp: 0.1161, G/loss_fake: -3.7941, G/loss_rec: 0.2385, G/loss_cls: 0.0003
# Saved real and fake images into stargan/samples/31500-images.jpg...
# Elapsed [1:51:22], Iteration [31600/100000], D/loss_real: -0.8561, D/loss_fake: 0.1607, D/loss_cls: 0.0025, D/loss_gp: 0.0003, G/loss_fake: -0.1512, G/loss_rec: 0.1385, G/loss_cls: 0.0018
# Elapsed [1:52:04], Iteration [31800/100000], D/loss_real: -1.9264, D/loss_fake: 1.3143, D/loss_cls: 0.0216, D/loss_gp: 0.0028, G/loss_fake: -1.5746, G/loss_rec: 0.1434, G/loss_cls: 0.0335
# Elapsed [1:52:46], Iteration [32000/100000], D/loss_real: -3.6926, D/loss_fake: 3.1251, D/loss_cls: 0.0187, D/loss_gp: 0.0006, G/loss_fake: -3.0235, G/loss_rec: 0.1535, G/loss_cls: 0.0187
# Saved real and fake images into stargan/samples/32000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [1:53:30], Iteration [32200/100000], D/loss_real: -1.7576, D/loss_fake: 1.3679, D/loss_cls: 0.1322, D/loss_gp: 0.0101, G/loss_fake: -1.2531, G/loss_rec: 0.2688, G/loss_cls: 0.1092
# Elapsed [1:54:12], Iteration [32400/100000], D/loss_real: -2.6060, D/loss_fake: 1.3685, D/loss_cls: 0.4493, D/loss_gp: 0.0015, G/loss_fake: -0.9125, G/loss_rec: 0.1883, G/loss_cls: 0.0180
# Saved real and fake images into stargan/samples/32500-images.jpg...
# Elapsed [1:54:54], Iteration [32600/100000], D/loss_real: -3.9654, D/loss_fake: 2.1167, D/loss_cls: 0.1327, D/loss_gp: 0.0029, G/loss_fake: -2.0630, G/loss_rec: 0.3030, G/loss_cls: 0.6493
# Elapsed [1:55:36], Iteration [32800/100000], D/loss_real: -1.4300, D/loss_fake: 0.0903, D/loss_cls: 1.5896, D/loss_gp: 0.0044, G/loss_fake: -0.3354, G/loss_rec: 0.1697, G/loss_cls: 0.3485
# Elapsed [1:56:19], Iteration [33000/100000], D/loss_real: -3.1881, D/loss_fake: 2.1495, D/loss_cls: 1.3307, D/loss_gp: 0.0068, G/loss_fake: -2.0298, G/loss_rec: 0.1829, G/loss_cls: 0.2502
# Saved real and fake images into stargan/samples/33000-images.jpg...
# Elapsed [1:57:01], Iteration [33200/100000], D/loss_real: -0.1274, D/loss_fake: -1.2540, D/loss_cls: 0.5314, D/loss_gp: 0.0072, G/loss_fake: 1.9829, G/loss_rec: 0.2195, G/loss_cls: 0.0046
# Elapsed [1:57:43], Iteration [33400/100000], D/loss_real: -2.4209, D/loss_fake: 1.5211, D/loss_cls: 0.3803, D/loss_gp: 0.0007, G/loss_fake: -1.3726, G/loss_rec: 0.2387, G/loss_cls: 0.0262
# Saved real and fake images into stargan/samples/33500-images.jpg...
# Elapsed [1:58:25], Iteration [33600/100000], D/loss_real: -4.7013, D/loss_fake: 2.0279, D/loss_cls: 0.2219, D/loss_gp: 0.0177, G/loss_fake: -3.6239, G/loss_rec: 0.1939, G/loss_cls: 0.0001
# Elapsed [1:59:08], Iteration [33800/100000], D/loss_real: -1.8881, D/loss_fake: 1.1053, D/loss_cls: 0.0093, D/loss_gp: 0.0024, G/loss_fake: -0.7698, G/loss_rec: 0.1254, G/loss_cls: 0.0103
# Elapsed [1:59:50], Iteration [34000/100000], D/loss_real: -1.8862, D/loss_fake: 1.7238, D/loss_cls: 0.0199, D/loss_gp: 0.0085, G/loss_fake: -1.6726, G/loss_rec: 0.1465, G/loss_cls: 0.0003
# Saved real and fake images into stargan/samples/34000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [2:00:33], Iteration [34200/100000], D/loss_real: -2.3777, D/loss_fake: -0.3420, D/loss_cls: 0.0529, D/loss_gp: 0.0238, G/loss_fake: 0.5443, G/loss_rec: 0.1657, G/loss_cls: 1.3844
# Elapsed [2:01:15], Iteration [34400/100000], D/loss_real: -2.3979, D/loss_fake: 1.4577, D/loss_cls: 1.0828, D/loss_gp: 0.0006, G/loss_fake: -0.9764, G/loss_rec: 0.1712, G/loss_cls: 0.0007
# Saved real and fake images into stargan/samples/34500-images.jpg...
# Elapsed [2:01:57], Iteration [34600/100000], D/loss_real: -4.3053, D/loss_fake: 3.2847, D/loss_cls: 2.6413, D/loss_gp: 0.0009, G/loss_fake: -2.3261, G/loss_rec: 0.1815, G/loss_cls: 0.0293
# Elapsed [2:02:40], Iteration [34800/100000], D/loss_real: -1.0934, D/loss_fake: 0.7722, D/loss_cls: 0.0076, D/loss_gp: 0.0084, G/loss_fake: -0.3345, G/loss_rec: 0.1274, G/loss_cls: 0.0012
# Elapsed [2:03:22], Iteration [35000/100000], D/loss_real: -4.7206, D/loss_fake: 3.6888, D/loss_cls: 0.0036, D/loss_gp: 0.0058, G/loss_fake: -3.8818, G/loss_rec: 0.1416, G/loss_cls: 0.0071
# Saved real and fake images into stargan/samples/35000-images.jpg...
# Elapsed [2:04:04], Iteration [35200/100000], D/loss_real: -3.3467, D/loss_fake: 1.2749, D/loss_cls: 0.0450, D/loss_gp: 0.0305, G/loss_fake: -1.2732, G/loss_rec: 0.2186, G/loss_cls: 0.0152
# Elapsed [2:04:46], Iteration [35400/100000], D/loss_real: -1.8814, D/loss_fake: 0.9478, D/loss_cls: 0.0000, D/loss_gp: 0.0163, G/loss_fake: -1.1484, G/loss_rec: 0.1799, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/35500-images.jpg...
# Elapsed [2:05:29], Iteration [35600/100000], D/loss_real: -1.5802, D/loss_fake: 0.4197, D/loss_cls: 0.0149, D/loss_gp: 0.0213, G/loss_fake: -0.6030, G/loss_rec: 0.1609, G/loss_cls: 0.0088
# Elapsed [2:06:11], Iteration [35800/100000], D/loss_real: -5.4849, D/loss_fake: 3.3902, D/loss_cls: 0.0010, D/loss_gp: 0.0026, G/loss_fake: -2.8950, G/loss_rec: 0.2451, G/loss_cls: 0.0007
# Elapsed [2:06:53], Iteration [36000/100000], D/loss_real: -2.9741, D/loss_fake: 0.3114, D/loss_cls: 0.9034, D/loss_gp: 0.0419, G/loss_fake: -0.4272, G/loss_rec: 0.2383, G/loss_cls: 0.0028
# Saved real and fake images into stargan/samples/36000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [2:07:36], Iteration [36200/100000], D/loss_real: -1.5640, D/loss_fake: 0.6920, D/loss_cls: 1.3565, D/loss_gp: 0.0004, G/loss_fake: -0.4124, G/loss_rec: 0.1434, G/loss_cls: 0.1952
# Elapsed [2:08:18], Iteration [36400/100000], D/loss_real: -6.3541, D/loss_fake: 4.6285, D/loss_cls: 1.4987, D/loss_gp: 0.0603, G/loss_fake: -3.3799, G/loss_rec: 0.2075, G/loss_cls: 0.0703
# Saved real and fake images into stargan/samples/36500-images.jpg...
# Elapsed [2:09:01], Iteration [36600/100000], D/loss_real: -1.3890, D/loss_fake: 0.6444, D/loss_cls: 0.2123, D/loss_gp: 0.0011, G/loss_fake: -0.4847, G/loss_rec: 0.2186, G/loss_cls: 0.0325
# Elapsed [2:09:43], Iteration [36800/100000], D/loss_real: -1.6304, D/loss_fake: 0.8357, D/loss_cls: 0.0351, D/loss_gp: 0.0004, G/loss_fake: -0.3836, G/loss_rec: 0.2148, G/loss_cls: 0.0001
# Elapsed [2:10:25], Iteration [37000/100000], D/loss_real: -1.2016, D/loss_fake: 1.3180, D/loss_cls: 0.3563, D/loss_gp: 0.0072, G/loss_fake: -1.4384, G/loss_rec: 0.2151, G/loss_cls: 0.0010
# Saved real and fake images into stargan/samples/37000-images.jpg...
# Elapsed [2:11:07], Iteration [37200/100000], D/loss_real: -2.0201, D/loss_fake: 1.0925, D/loss_cls: 0.2855, D/loss_gp: 0.0009, G/loss_fake: -1.0070, G/loss_rec: 0.1794, G/loss_cls: 1.8469
# Elapsed [2:11:49], Iteration [37400/100000], D/loss_real: -1.4149, D/loss_fake: 0.9425, D/loss_cls: 1.3874, D/loss_gp: 0.0005, G/loss_fake: -0.2104, G/loss_rec: 0.2371, G/loss_cls: 0.6874
# Saved real and fake images into stargan/samples/37500-images.jpg...
# Elapsed [2:12:32], Iteration [37600/100000], D/loss_real: 0.0387, D/loss_fake: -0.7748, D/loss_cls: 0.1317, D/loss_gp: 0.0063, G/loss_fake: 0.6506, G/loss_rec: 0.1519, G/loss_cls: 0.0430
# Elapsed [2:13:14], Iteration [37800/100000], D/loss_real: -1.0714, D/loss_fake: -0.2912, D/loss_cls: 0.1029, D/loss_gp: 0.0088, G/loss_fake: 0.8936, G/loss_rec: 0.1597, G/loss_cls: 0.0067
# Elapsed [2:13:56], Iteration [38000/100000], D/loss_real: -2.5575, D/loss_fake: 2.4739, D/loss_cls: 0.0010, D/loss_gp: 0.0100, G/loss_fake: -1.8966, G/loss_rec: 0.1890, G/loss_cls: 0.0001
# Saved real and fake images into stargan/samples/38000-images.jpg...
# Saved model checkpoints into stargan/models...
# Elapsed [2:14:39], Iteration [38200/100000], D/loss_real: -0.4510, D/loss_fake: -0.2625, D/loss_cls: 0.0162, D/loss_gp: 0.0044, G/loss_fake: 0.3986, G/loss_rec: 0.1663, G/loss_cls: 0.0014
# Elapsed [2:15:21], Iteration [38400/100000], D/loss_real: -2.0201, D/loss_fake: 1.5487, D/loss_cls: 0.1767, D/loss_gp: 0.0003, G/loss_fake: -1.4872, G/loss_rec: 0.2053, G/loss_cls: 0.0262
# ...
# Decayed learning rates, g_lr: 9.916399999999817e-05, d_lr: 9.916399999999817e-05.
# Decayed learning rates, g_lr: 9.916199999999817e-05, d_lr: 9.916199999999817e-05.
# Elapsed [5:24:25], Iteration [92000/100000], D/loss_real: -1.8168, D/loss_fake: -0.0806, D/loss_cls: 0.0044, D/loss_gp: 0.0347, G/loss_fake: 0.0872, G/loss_rec: 0.2366, G/loss_cls: 0.0245
# Saved real and fake images into stargan/samples/92000-images.jpg...
# Saved model checkpoints into stargan/models...
# Decayed learning rates, g_lr: 9.915999999999816e-05, d_lr: 9.915999999999816e-05.
# Decayed learning rates, g_lr: 9.915799999999816e-05, d_lr: 9.915799999999816e-05.
# Elapsed [5:25:08], Iteration [92200/100000], D/loss_real: -0.7680, D/loss_fake: -0.2165, D/loss_cls: 0.0120, D/loss_gp: 0.0039, G/loss_fake: 0.2154, G/loss_rec: 0.1626, G/loss_cls: 0.3217
# Decayed learning rates, g_lr: 9.915599999999815e-05, d_lr: 9.915599999999815e-05.
# Decayed learning rates, g_lr: 9.915399999999815e-05, d_lr: 9.915399999999815e-05.
# Elapsed [5:25:50], Iteration [92400/100000], D/loss_real: -1.0326, D/loss_fake: 0.3343, D/loss_cls: 0.0000, D/loss_gp: 0.0200, G/loss_fake: -0.1261, G/loss_rec: 0.2019, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.915199999999815e-05, d_lr: 9.915199999999815e-05.
# Saved real and fake images into stargan/samples/92500-images.jpg...
# Decayed learning rates, g_lr: 9.914999999999814e-05, d_lr: 9.914999999999814e-05.
# Elapsed [5:26:33], Iteration [92600/100000], D/loss_real: -2.9174, D/loss_fake: 1.7932, D/loss_cls: 0.0017, D/loss_gp: 0.0011, G/loss_fake: -1.7614, G/loss_rec: 0.1550, G/loss_cls: 0.0001
# Decayed learning rates, g_lr: 9.914799999999814e-05, d_lr: 9.914799999999814e-05.
# Decayed learning rates, g_lr: 9.914599999999813e-05, d_lr: 9.914599999999813e-05.
# Elapsed [5:27:15], Iteration [92800/100000], D/loss_real: -1.4692, D/loss_fake: -0.2401, D/loss_cls: 0.0193, D/loss_gp: 0.0020, G/loss_fake: 0.2406, G/loss_rec: 0.2200, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.914399999999813e-05, d_lr: 9.914399999999813e-05.
# Decayed learning rates, g_lr: 9.914199999999812e-05, d_lr: 9.914199999999812e-05.
# Elapsed [5:27:57], Iteration [93000/100000], D/loss_real: -1.0623, D/loss_fake: 0.5714, D/loss_cls: 0.0000, D/loss_gp: 0.0050, G/loss_fake: -0.4222, G/loss_rec: 0.1768, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/93000-images.jpg...
# Decayed learning rates, g_lr: 9.913999999999812e-05, d_lr: 9.913999999999812e-05.
# Decayed learning rates, g_lr: 9.913799999999811e-05, d_lr: 9.913799999999811e-05.
# Elapsed [5:28:40], Iteration [93200/100000], D/loss_real: -1.7167, D/loss_fake: 0.8730, D/loss_cls: 0.0343, D/loss_gp: 0.0126, G/loss_fake: -0.7449, G/loss_rec: 0.1504, G/loss_cls: 0.0276
# Decayed learning rates, g_lr: 9.913599999999811e-05, d_lr: 9.913599999999811e-05.
# Decayed learning rates, g_lr: 9.91339999999981e-05, d_lr: 9.91339999999981e-05.
# Elapsed [5:29:22], Iteration [93400/100000], D/loss_real: -1.7155, D/loss_fake: 0.4169, D/loss_cls: 0.0001, D/loss_gp: 0.0040, G/loss_fake: -0.2656, G/loss_rec: 0.1749, G/loss_cls: 0.3255
# Decayed learning rates, g_lr: 9.91319999999981e-05, d_lr: 9.91319999999981e-05.
# Saved real and fake images into stargan/samples/93500-images.jpg...
# Decayed learning rates, g_lr: 9.91299999999981e-05, d_lr: 9.91299999999981e-05.
# Elapsed [5:30:04], Iteration [93600/100000], D/loss_real: -1.8762, D/loss_fake: -0.1628, D/loss_cls: 0.0465, D/loss_gp: 0.0089, G/loss_fake: 0.1467, G/loss_rec: 0.1440, G/loss_cls: 0.0063
# Decayed learning rates, g_lr: 9.912799999999809e-05, d_lr: 9.912799999999809e-05.
# Decayed learning rates, g_lr: 9.912599999999809e-05, d_lr: 9.912599999999809e-05.
# Elapsed [5:30:46], Iteration [93800/100000], D/loss_real: -1.1040, D/loss_fake: 0.7427, D/loss_cls: 0.0000, D/loss_gp: 0.0015, G/loss_fake: -0.7709, G/loss_rec: 0.1274, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.912399999999808e-05, d_lr: 9.912399999999808e-05.
# Decayed learning rates, g_lr: 9.912199999999808e-05, d_lr: 9.912199999999808e-05.
# Elapsed [5:31:29], Iteration [94000/100000], D/loss_real: -2.1417, D/loss_fake: 1.5167, D/loss_cls: 0.0001, D/loss_gp: 0.0111, G/loss_fake: -1.4819, G/loss_rec: 0.1836, G/loss_cls: 0.0004
# Saved real and fake images into stargan/samples/94000-images.jpg...
# Saved model checkpoints into stargan/models...
# Decayed learning rates, g_lr: 9.911999999999808e-05, d_lr: 9.911999999999808e-05.
# Decayed learning rates, g_lr: 9.911799999999807e-05, d_lr: 9.911799999999807e-05.
# Elapsed [5:32:12], Iteration [94200/100000], D/loss_real: -1.5955, D/loss_fake: -0.0906, D/loss_cls: 0.0002, D/loss_gp: 0.0240, G/loss_fake: -0.0485, G/loss_rec: 0.1893, G/loss_cls: 0.0044
# Decayed learning rates, g_lr: 9.911599999999807e-05, d_lr: 9.911599999999807e-05.
# Decayed learning rates, g_lr: 9.911399999999806e-05, d_lr: 9.911399999999806e-05.
# Elapsed [5:32:54], Iteration [94400/100000], D/loss_real: -1.2975, D/loss_fake: -0.0777, D/loss_cls: 0.3965, D/loss_gp: 0.0039, G/loss_fake: -0.0214, G/loss_rec: 0.1800, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.911199999999806e-05, d_lr: 9.911199999999806e-05.
# Saved real and fake images into stargan/samples/94500-images.jpg...
# Decayed learning rates, g_lr: 9.910999999999805e-05, d_lr: 9.910999999999805e-05.
# Elapsed [5:33:37], Iteration [94600/100000], D/loss_real: -1.4279, D/loss_fake: 0.5801, D/loss_cls: 0.5117, D/loss_gp: 0.0046, G/loss_fake: -0.6390, G/loss_rec: 0.2032, G/loss_cls: 0.0002
# Decayed learning rates, g_lr: 9.910799999999805e-05, d_lr: 9.910799999999805e-05.
# Decayed learning rates, g_lr: 9.910599999999804e-05, d_lr: 9.910599999999804e-05.
# Elapsed [5:34:19], Iteration [94800/100000], D/loss_real: -1.9593, D/loss_fake: 1.6647, D/loss_cls: 0.0000, D/loss_gp: 0.0045, G/loss_fake: -1.7090, G/loss_rec: 0.1497, G/loss_cls: 0.0007
# Decayed learning rates, g_lr: 9.910399999999804e-05, d_lr: 9.910399999999804e-05.
# Decayed learning rates, g_lr: 9.910199999999804e-05, d_lr: 9.910199999999804e-05.
# Elapsed [5:35:01], Iteration [95000/100000], D/loss_real: -1.7405, D/loss_fake: 0.7658, D/loss_cls: 3.2819, D/loss_gp: 0.0033, G/loss_fake: -0.6916, G/loss_rec: 0.1715, G/loss_cls: 0.0102
# Saved real and fake images into stargan/samples/95000-images.jpg...
# Decayed learning rates, g_lr: 9.909999999999803e-05, d_lr: 9.909999999999803e-05.
# Decayed learning rates, g_lr: 9.909799999999803e-05, d_lr: 9.909799999999803e-05.
# Elapsed [5:35:44], Iteration [95200/100000], D/loss_real: -1.1493, D/loss_fake: 0.4271, D/loss_cls: 0.1803, D/loss_gp: 0.0037, G/loss_fake: -0.2140, G/loss_rec: 0.1183, G/loss_cls: 0.0005
# Decayed learning rates, g_lr: 9.909599999999802e-05, d_lr: 9.909599999999802e-05.
# Decayed learning rates, g_lr: 9.909399999999802e-05, d_lr: 9.909399999999802e-05.
# Elapsed [5:36:26], Iteration [95400/100000], D/loss_real: -0.8032, D/loss_fake: -0.0688, D/loss_cls: 0.0000, D/loss_gp: 0.0173, G/loss_fake: -0.0218, G/loss_rec: 0.1953, G/loss_cls: 0.0006
# Decayed learning rates, g_lr: 9.909199999999801e-05, d_lr: 9.909199999999801e-05.
# Saved real and fake images into stargan/samples/95500-images.jpg...
# Decayed learning rates, g_lr: 9.908999999999801e-05, d_lr: 9.908999999999801e-05.
# Elapsed [5:37:08], Iteration [95600/100000], D/loss_real: -2.4931, D/loss_fake: 1.5229, D/loss_cls: 0.0012, D/loss_gp: 0.0012, G/loss_fake: -1.0193, G/loss_rec: 0.1723, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.9087999999998e-05, d_lr: 9.9087999999998e-05.
# Decayed learning rates, g_lr: 9.9085999999998e-05, d_lr: 9.9085999999998e-05.
# Elapsed [5:37:50], Iteration [95800/100000], D/loss_real: -1.7022, D/loss_fake: 0.6065, D/loss_cls: 0.0000, D/loss_gp: 0.0225, G/loss_fake: -0.5182, G/loss_rec: 0.1711, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.9083999999998e-05, d_lr: 9.9083999999998e-05.
# Decayed learning rates, g_lr: 9.908199999999799e-05, d_lr: 9.908199999999799e-05.
# Elapsed [5:38:32], Iteration [96000/100000], D/loss_real: -1.0711, D/loss_fake: -0.8979, D/loss_cls: 0.0011, D/loss_gp: 0.0053, G/loss_fake: 0.6289, G/loss_rec: 0.1760, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/96000-images.jpg...
# Saved model checkpoints into stargan/models...
# Decayed learning rates, g_lr: 9.907999999999799e-05, d_lr: 9.907999999999799e-05.
# Decayed learning rates, g_lr: 9.907799999999798e-05, d_lr: 9.907799999999798e-05.
# Elapsed [5:39:16], Iteration [96200/100000], D/loss_real: -0.9773, D/loss_fake: -0.5197, D/loss_cls: 0.2734, D/loss_gp: 0.0000, G/loss_fake: 0.7836, G/loss_rec: 0.1973, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.907599999999798e-05, d_lr: 9.907599999999798e-05.
# Decayed learning rates, g_lr: 9.907399999999797e-05, d_lr: 9.907399999999797e-05.
# Elapsed [5:39:58], Iteration [96400/100000], D/loss_real: -0.0459, D/loss_fake: -1.4096, D/loss_cls: 0.0012, D/loss_gp: 0.0244, G/loss_fake: 1.5301, G/loss_rec: 0.1462, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.907199999999797e-05, d_lr: 9.907199999999797e-05.
# Saved real and fake images into stargan/samples/96500-images.jpg...
# Decayed learning rates, g_lr: 9.906999999999797e-05, d_lr: 9.906999999999797e-05.
# Elapsed [5:40:40], Iteration [96600/100000], D/loss_real: -2.3209, D/loss_fake: 0.4241, D/loss_cls: 0.0001, D/loss_gp: 0.0043, G/loss_fake: -0.3391, G/loss_rec: 0.1628, G/loss_cls: 0.0008
# Decayed learning rates, g_lr: 9.906799999999796e-05, d_lr: 9.906799999999796e-05.
# Decayed learning rates, g_lr: 9.906599999999796e-05, d_lr: 9.906599999999796e-05.
# Elapsed [5:41:22], Iteration [96800/100000], D/loss_real: -0.8604, D/loss_fake: 0.2455, D/loss_cls: 0.0008, D/loss_gp: 0.0068, G/loss_fake: -0.2022, G/loss_rec: 0.1786, G/loss_cls: 0.0001
# Decayed learning rates, g_lr: 9.906399999999795e-05, d_lr: 9.906399999999795e-05.
# Decayed learning rates, g_lr: 9.906199999999795e-05, d_lr: 9.906199999999795e-05.
# Elapsed [5:42:05], Iteration [97000/100000], D/loss_real: -0.8198, D/loss_fake: -0.1136, D/loss_cls: 0.0203, D/loss_gp: 0.0161, G/loss_fake: 0.1702, G/loss_rec: 0.1696, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/97000-images.jpg...
# Decayed learning rates, g_lr: 9.905999999999794e-05, d_lr: 9.905999999999794e-05.
# Decayed learning rates, g_lr: 9.905799999999794e-05, d_lr: 9.905799999999794e-05.
# Elapsed [5:42:47], Iteration [97200/100000], D/loss_real: -1.8902, D/loss_fake: 1.4088, D/loss_cls: 2.4689, D/loss_gp: 0.0067, G/loss_fake: -1.1903, G/loss_rec: 0.1953, G/loss_cls: 0.0018
# Decayed learning rates, g_lr: 9.905599999999793e-05, d_lr: 9.905599999999793e-05.
# Decayed learning rates, g_lr: 9.905399999999793e-05, d_lr: 9.905399999999793e-05.
# Elapsed [5:43:29], Iteration [97400/100000], D/loss_real: -3.0959, D/loss_fake: 1.7496, D/loss_cls: 0.0001, D/loss_gp: 0.0011, G/loss_fake: -1.8041, G/loss_rec: 0.2112, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.905199999999793e-05, d_lr: 9.905199999999793e-05.
# Saved real and fake images into stargan/samples/97500-images.jpg...
# Decayed learning rates, g_lr: 9.904999999999792e-05, d_lr: 9.904999999999792e-05.
# Elapsed [5:44:12], Iteration [97600/100000], D/loss_real: -1.7476, D/loss_fake: 0.7621, D/loss_cls: 0.0000, D/loss_gp: 0.0075, G/loss_fake: -0.6078, G/loss_rec: 0.1530, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.904799999999792e-05, d_lr: 9.904799999999792e-05.
# Decayed learning rates, g_lr: 9.904599999999791e-05, d_lr: 9.904599999999791e-05.
# Elapsed [5:44:54], Iteration [97800/100000], D/loss_real: -0.5560, D/loss_fake: -0.5745, D/loss_cls: 0.0000, D/loss_gp: 0.0464, G/loss_fake: 0.6706, G/loss_rec: 0.1451, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.904399999999791e-05, d_lr: 9.904399999999791e-05.
# Decayed learning rates, g_lr: 9.90419999999979e-05, d_lr: 9.90419999999979e-05.
# Elapsed [5:45:36], Iteration [98000/100000], D/loss_real: -2.8177, D/loss_fake: 0.1052, D/loss_cls: 0.0531, D/loss_gp: 0.0058, G/loss_fake: -0.1235, G/loss_rec: 0.1793, G/loss_cls: 0.0000
# Saved real and fake images into stargan/samples/98000-images.jpg...
# Saved model checkpoints into stargan/models...
# Decayed learning rates, g_lr: 9.90399999999979e-05, d_lr: 9.90399999999979e-05.
# Decayed learning rates, g_lr: 9.90379999999979e-05, d_lr: 9.90379999999979e-05.
# Elapsed [5:46:20], Iteration [98200/100000], D/loss_real: -1.4061, D/loss_fake: 0.6817, D/loss_cls: 4.3189, D/loss_gp: 0.0040, G/loss_fake: -0.4975, G/loss_rec: 0.1642, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.903599999999789e-05, d_lr: 9.903599999999789e-05.
# Decayed learning rates, g_lr: 9.903399999999789e-05, d_lr: 9.903399999999789e-05.
# Elapsed [5:47:02], Iteration [98400/100000], D/loss_real: -2.5485, D/loss_fake: 0.9195, D/loss_cls: 0.0000, D/loss_gp: 0.0158, G/loss_fake: -0.8270, G/loss_rec: 0.1910, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.903199999999788e-05, d_lr: 9.903199999999788e-05.
# Saved real and fake images into stargan/samples/98500-images.jpg...
# Decayed learning rates, g_lr: 9.902999999999788e-05, d_lr: 9.902999999999788e-05.
# Elapsed [5:47:44], Iteration [98600/100000], D/loss_real: -2.1200, D/loss_fake: 0.2540, D/loss_cls: 0.0000, D/loss_gp: 0.0008, G/loss_fake: -0.3394, G/loss_rec: 0.2087, G/loss_cls: 2.3627
# Decayed learning rates, g_lr: 9.902799999999787e-05, d_lr: 9.902799999999787e-05.
# Decayed learning rates, g_lr: 9.902599999999787e-05, d_lr: 9.902599999999787e-05.
# Elapsed [5:48:27], Iteration [98800/100000], D/loss_real: -1.7427, D/loss_fake: 0.5161, D/loss_cls: 0.0000, D/loss_gp: 0.1252, G/loss_fake: 0.6263, G/loss_rec: 0.1521, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.902399999999786e-05, d_lr: 9.902399999999786e-05.
# Decayed learning rates, g_lr: 9.902199999999786e-05, d_lr: 9.902199999999786e-05.
# Elapsed [5:49:09], Iteration [99000/100000], D/loss_real: -0.0525, D/loss_fake: -0.5943, D/loss_cls: 0.0003, D/loss_gp: 0.0010, G/loss_fake: 0.7260, G/loss_rec: 0.1348, G/loss_cls: 7.5880
# Saved real and fake images into stargan/samples/99000-images.jpg...
# Decayed learning rates, g_lr: 9.901999999999786e-05, d_lr: 9.901999999999786e-05.
# Decayed learning rates, g_lr: 9.901799999999785e-05, d_lr: 9.901799999999785e-05.
# Elapsed [5:49:51], Iteration [99200/100000], D/loss_real: -2.3444, D/loss_fake: 1.3811, D/loss_cls: 0.0070, D/loss_gp: 0.0038, G/loss_fake: -1.4123, G/loss_rec: 0.1595, G/loss_cls: 0.0443
# Decayed learning rates, g_lr: 9.901599999999785e-05, d_lr: 9.901599999999785e-05.
# Decayed learning rates, g_lr: 9.901399999999784e-05, d_lr: 9.901399999999784e-05.
# Elapsed [5:50:33], Iteration [99400/100000], D/loss_real: -1.1475, D/loss_fake: 0.5372, D/loss_cls: 0.0268, D/loss_gp: 0.0028, G/loss_fake: -0.2178, G/loss_rec: 0.1845, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.901199999999784e-05, d_lr: 9.901199999999784e-05.
# Saved real and fake images into stargan/samples/99500-images.jpg...
# Decayed learning rates, g_lr: 9.900999999999783e-05, d_lr: 9.900999999999783e-05.
# Elapsed [5:51:16], Iteration [99600/100000], D/loss_real: -2.3484, D/loss_fake: 2.1113, D/loss_cls: 0.0020, D/loss_gp: 0.0069, G/loss_fake: -2.1301, G/loss_rec: 0.1020, G/loss_cls: 0.0000
# Decayed learning rates, g_lr: 9.900799999999783e-05, d_lr: 9.900799999999783e-05.
# Decayed learning rates, g_lr: 9.900599999999783e-05, d_lr: 9.900599999999783e-05.
# Elapsed [5:51:58], Iteration [99800/100000], D/loss_real: -1.3594, D/loss_fake: 0.4166, D/loss_cls: 0.0194, D/loss_gp: 0.0034, G/loss_fake: -0.4098, G/loss_rec: 0.1490, G/loss_cls: 0.0003
# Decayed learning rates, g_lr: 9.900399999999782e-05, d_lr: 9.900399999999782e-05.
# Decayed learning rates, g_lr: 9.900199999999782e-05, d_lr: 9.900199999999782e-05.
# Elapsed [5:52:40], Iteration [100000/100000], D/loss_real: -1.1518, D/loss_fake: 0.7467, D/loss_cls: 0.0000, D/loss_gp: 0.0008, G/loss_fake: -0.6370, G/loss_rec: 0.0892, G/loss_cls: 0.0001
# Saved real and fake images into stargan/samples/100000-images.jpg...
# Saved model checkpoints into stargan/models...
# Decayed learning rates, g_lr: 9.899999999999781e-05, d_lr: 9.899999999999781e-05.

# %% [markdown]
# ### Testing: Image Generation

# %%
run(TEST_IMG_DIR, 'test')
# Out:
# Namespace(attr_path='data/celeba/list_attr_celeba.txt', batch_size=2, beta1=0.5, beta2=0.999, c2_dim=8, c_dim=5, celeba_crop_size=178, celeba_image_dir='data/celeba/images', d_conv_dim=64, d_lr=0.0001, d_repeat_num=6, dataset='RaFD', g_conv_dim=64, g_lr=0.0001, g_repeat_num=6, image_size=256, lambda_cls=1, lambda_gp=10, lambda_rec=10, log_dir='stargan/logs', log_step=200, lr_update_step=100, mode='test', model_save_dir='stargan/models', model_save_step=2000, n_critic=5, num_iters=100000, num_iters_decay=50000, num_workers=1, rafd_crop_size=256, rafd_image_dir='data/style/test', result_dir='stargan/results', resume_iters=None, sample_dir='stargan/samples', sample_step=500, selected_attrs=['Black_Hair', 'Blond_Hair', 'Brown_Hair', 'Male', 'Young'], test_iters=100000, use_tensorboard=True)
# Generator(
#   (main): Sequential(
#     (0): Conv2d(8, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): ResidualBlock(
#       (main): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (16): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU(inplace=True)
#     (18): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (19): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (20): ReLU(inplace=True)
#     (21): Conv2d(64, 3, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     (22): Tanh()
#   )
# )
# G
# The number of parameters: 8430528
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01)
#     (8): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01)
#     (10): Conv2d(1024, 2048, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01)
#   )
#   (conv1): Conv2d(2048, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (conv2): Conv2d(2048, 5, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )
# D
# The number of parameters: 44884928
# Loading the trained models from step 100000...
# Saved real and fake images into stargan/results/1-images.jpg...
# Saved real and fake images into stargan/results/2-images.jpg...
# Saved real and fake images into stargan/results/3-images.jpg...
# Saved real and fake images into stargan/results/4-images.jpg...
# Saved real and fake images into stargan/results/5-images.jpg...
# Saved real and fake images into stargan/results/6-images.jpg...
# Saved real and fake images into stargan/results/7-images.jpg...
# Saved real and fake images into stargan/results/8-images.jpg...
# Saved real and fake images into stargan/results/9-images.jpg...
# Saved real and fake images into stargan/results/10-images.jpg...
# Saved real and fake images into stargan/results/11-images.jpg...
# Saved real and fake images into stargan/results/12-images.jpg...
# Saved real and fake images into stargan/results/13-images.jpg...
# Saved real and fake images into stargan/results/14-images.jpg...
# Saved real and fake images into stargan/results/15-images.jpg...
# Saved real and fake images into stargan/results/16-images.jpg...
# Saved real and fake images into stargan/results/17-images.jpg...
# Saved real and fake images into stargan/results/18-images.jpg...
# Saved real and fake images into stargan/results/19-images.jpg...
# Saved real and fake images into stargan/results/20-images.jpg...
# Saved real and fake images into stargan/results/21-images.jpg...
# Saved real and fake images into stargan/results/22-images.jpg...
# Saved real and fake images into stargan/results/23-images.jpg...
# Saved real and fake images into stargan/results/24-images.jpg...
# Saved real and fake images into stargan/results/25-images.jpg...
# Saved real and fake images into stargan/results/26-images.jpg...
# Saved real and fake images into stargan/results/27-images.jpg...
# Saved real and fake images into stargan/results/28-images.jpg...
# Saved real and fake images into stargan/results/29-images.jpg...
# Saved real and fake images into stargan/results/30-images.jpg...
# Saved real and fake images into stargan/results/31-images.jpg...
# Saved real and fake images into stargan/results/32-images.jpg...
# Saved real and fake images into stargan/results/33-images.jpg...
# Saved real and fake images into stargan/results/34-images.jpg...
# Saved real and fake images into stargan/results/35-images.jpg...
# Saved real and fake images into stargan/results/36-images.jpg...
# Saved real and fake images into stargan/results/37-images.jpg...
# Saved real and fake images into stargan/results/38-images.jpg...
# Saved real and fake images into stargan/results/39-images.jpg...
# Saved real and fake images into stargan/results/40-images.jpg...
# Saved real and fake images into stargan/results/41-images.jpg...
# Saved real and fake images into stargan/results/42-images.jpg...
# Saved real and fake images into stargan/results/43-images.jpg...
# Saved real and fake images into stargan/results/44-images.jpg...
# Saved real and fake images into stargan/results/45-images.jpg...
# Saved real and fake images into stargan/results/46-images.jpg...
# Saved real and fake images into stargan/results/47-images.jpg...
# Saved real and fake images into stargan/results/48-images.jpg...
# Saved real and fake images into stargan/results/49-images.jpg...
# Saved real and fake images into stargan/results/50-images.jpg...
# Saved real and fake images into stargan/results/51-images.jpg...
# Saved real and fake images into stargan/results/52-images.jpg...
# Saved real and fake images into stargan/results/53-images.jpg...
# Saved real and fake images into stargan/results/54-images.jpg...
# Saved real and fake images into stargan/results/55-images.jpg...
# Saved real and fake images into stargan/results/56-images.jpg...
# Saved real and fake images into stargan/results/57-images.jpg...
# Saved real and fake images into stargan/results/58-images.jpg...
# Saved real and fake images into stargan/results/59-images.jpg...
# Saved real and fake images into stargan/results/60-images.jpg...
# Saved real and fake images into stargan/results/61-images.jpg...
# Saved real and fake images into stargan/results/62-images.jpg...
# Saved real and fake images into stargan/results/63-images.jpg...
# Saved real and fake images into stargan/results/64-images.jpg...
# Saved real and fake images into stargan/results/65-images.jpg...
# Saved real and fake images into stargan/results/66-images.jpg...
# Saved real and fake images into stargan/results/67-images.jpg...
# Saved real and fake images into stargan/results/68-images.jpg...
# Saved real and fake images into stargan/results/69-images.jpg...
# Saved real and fake images into stargan/results/70-images.jpg...
# Saved real and fake images into stargan/results/71-images.jpg...
# Saved real and fake images into stargan/results/72-images.jpg...
# Saved real and fake images into stargan/results/73-images.jpg...
# Saved real and fake images into stargan/results/74-images.jpg...
# Saved real and fake images into stargan/results/75-images.jpg...
# Saved real and fake images into stargan/results/76-images.jpg...
# Saved real and fake images into stargan/results/77-images.jpg...
# Saved real and fake images into stargan/results/78-images.jpg...
# Saved real and fake images into stargan/results/79-images.jpg...
# Saved real and fake images into stargan/results/80-images.jpg...
# Saved real and fake images into stargan/results/81-images.jpg...
# Saved real and fake images into stargan/results/82-images.jpg...
# Saved real and fake images into stargan/results/83-images.jpg...
# Saved real and fake images into stargan/results/84-images.jpg...
# Saved real and fake images into stargan/results/85-images.jpg...
# Saved real and fake images into stargan/results/86-images.jpg...
# Saved real and fake images into stargan/results/87-images.jpg...
# Saved real and fake images into stargan/results/88-images.jpg...
# Saved real and fake images into stargan/results/89-images.jpg...
# Saved real and fake images into stargan/results/90-images.jpg...
# Saved real and fake images into stargan/results/91-images.jpg...
# Saved real and fake images into stargan/results/92-images.jpg...
# Saved real and fake images into stargan/results/93-images.jpg...
# Saved real and fake images into stargan/results/94-images.jpg...
# Saved real and fake images into stargan/results/95-images.jpg...
# Saved real and fake images into stargan/results/96-images.jpg...
# Saved real and fake images into stargan/results/97-images.jpg...
# Saved real and fake images into stargan/results/98-images.jpg...
# Saved real and fake images into stargan/results/99-images.jpg...
# Saved real and fake images into stargan/results/100-images.jpg...
# Saved real and fake images into stargan/results/101-images.jpg...
# Saved real and fake images into stargan/results/102-images.jpg...
# Saved real and fake images into stargan/results/103-images.jpg...
# Saved real and fake images into stargan/results/104-images.jpg...
# Saved real and fake images into stargan/results/105-images.jpg...
# Saved real and fake images into stargan/results/106-images.jpg...
# Saved real and fake images into stargan/results/107-images.jpg...
# Saved real and fake images into stargan/results/108-images.jpg...
# Saved real and fake images into stargan/results/109-images.jpg...
# Saved real and fake images into stargan/results/110-images.jpg...
# Saved real and fake images into stargan/results/111-images.jpg...
# Saved real and fake images into stargan/results/112-images.jpg...
# Saved real and fake images into stargan/results/113-images.jpg...
# Saved real and fake images into stargan/results/114-images.jpg...
# Saved real and fake images into stargan/results/115-images.jpg...
# Saved real and fake images into stargan/results/116-images.jpg...
# Saved real and fake images into stargan/results/117-images.jpg...
# Saved real and fake images into stargan/results/118-images.jpg...
# Saved real and fake images into stargan/results/119-images.jpg...
# Saved real and fake images into stargan/results/120-images.jpg...
# Saved real and fake images into stargan/results/121-images.jpg...
# Saved real and fake images into stargan/results/122-images.jpg...
# Saved real and fake images into stargan/results/123-images.jpg...
# Saved real and fake images into stargan/results/124-images.jpg...
# Saved real and fake images into stargan/results/125-images.jpg...
# Saved real and fake images into stargan/results/126-images.jpg...
# Saved real and fake images into stargan/results/127-images.jpg...
# Saved real and fake images into stargan/results/128-images.jpg...
# Saved real and fake images into stargan/results/129-images.jpg...
# Saved real and fake images into stargan/results/130-images.jpg...
# Saved real and fake images into stargan/results/131-images.jpg...
# Saved real and fake images into stargan/results/132-images.jpg...
# Saved real and fake images into stargan/results/133-images.jpg...
# Saved real and fake images into stargan/results/134-images.jpg...
# Saved real and fake images into stargan/results/135-images.jpg...
# Saved real and fake images into stargan/results/136-images.jpg...
# Saved real and fake images into stargan/results/137-images.jpg...
# Saved real and fake images into stargan/results/138-images.jpg...
# Saved real and fake images into stargan/results/139-images.jpg...
# Saved real and fake images into stargan/results/140-images.jpg...
# Saved real and fake images into stargan/results/141-images.jpg...
# Saved real and fake images into stargan/results/142-images.jpg...
# Saved real and fake images into stargan/results/143-images.jpg...
# Saved real and fake images into stargan/results/144-images.jpg...
# Saved real and fake images into stargan/results/145-images.jpg...
# Saved real and fake images into stargan/results/146-images.jpg...
# Saved real and fake images into stargan/results/147-images.jpg...
# Saved real and fake images into stargan/results/148-images.jpg...
# Saved real and fake images into stargan/results/149-images.jpg...
# Saved real and fake images into stargan/results/150-images.jpg...
# Saved real and fake images into stargan/results/151-images.jpg...
# Saved real and fake images into stargan/results/152-images.jpg...
# Saved real and fake images into stargan/results/153-images.jpg...
# Saved real and fake images into stargan/results/154-images.jpg...
# Saved real and fake images into stargan/results/155-images.jpg...
# Saved real and fake images into stargan/results/156-images.jpg...
# Saved real and fake images into stargan/results/157-images.jpg...
# Saved real and fake images into stargan/results/158-images.jpg...
# Saved real and fake images into stargan/results/159-images.jpg...
# Saved real and fake images into stargan/results/160-images.jpg...
# Saved real and fake images into stargan/results/161-images.jpg...
# Saved real and fake images into stargan/results/162-images.jpg...
# Saved real and fake images into stargan/results/163-images.jpg...
# Saved real and fake images into stargan/results/164-images.jpg...
# Saved real and fake images into stargan/results/165-images.jpg...
# Saved real and fake images into stargan/results/166-images.jpg...
# Saved real and fake images into stargan/results/167-images.jpg...
# Saved real and fake images into stargan/results/168-images.jpg...
# Saved real and fake images into stargan/results/169-images.jpg...
# Saved real and fake images into stargan/results/170-images.jpg...
# Saved real and fake images into stargan/results/171-images.jpg...
# Saved real and fake images into stargan/results/172-images.jpg...
# Saved real and fake images into stargan/results/173-images.jpg...
# Saved real and fake images into stargan/results/174-images.jpg...
# Saved real and fake images into stargan/results/175-images.jpg...
# Saved real and fake images into stargan/results/176-images.jpg...
# Saved real and fake images into stargan/results/177-images.jpg...
# Saved real and fake images into stargan/results/178-images.jpg...
# Saved real and fake images into stargan/results/179-images.jpg...
# Saved real and fake images into stargan/results/180-images.jpg...
# Saved real and fake images into stargan/results/181-images.jpg...
# Saved real and fake images into stargan/results/182-images.jpg...
# Saved real and fake images into stargan/results/183-images.jpg...
# Saved real and fake images into stargan/results/184-images.jpg...
# Saved real and fake images into stargan/results/185-images.jpg...
# Saved real and fake images into stargan/results/186-images.jpg...
# Saved real and fake images into stargan/results/187-images.jpg...
# Saved real and fake images into stargan/results/188-images.jpg...
# Saved real and fake images into stargan/results/189-images.jpg...
# Saved real and fake images into stargan/results/190-images.jpg...
# Saved real and fake images into stargan/results/191-images.jpg...
# Saved real and fake images into stargan/results/192-images.jpg...
# Saved real and fake images into stargan/results/193-images.jpg...
# Saved real and fake images into stargan/results/194-images.jpg...
# Saved real and fake images into stargan/results/195-images.jpg...
# Saved real and fake images into stargan/results/196-images.jpg...
# Saved real and fake images into stargan/results/197-images.jpg...
# Saved real and fake images into stargan/results/198-images.jpg...
# Saved real and fake images into stargan/results/199-images.jpg...
# Saved real and fake images into stargan/results/200-images.jpg...
# Saved real and fake images into stargan/results/201-images.jpg...
# Saved real and fake images into stargan/results/202-images.jpg...
# Saved real and fake images into stargan/results/203-images.jpg...
# Saved real and fake images into stargan/results/204-images.jpg...
# Saved real and fake images into stargan/results/205-images.jpg...
# Saved real and fake images into stargan/results/206-images.jpg...
# Saved real and fake images into stargan/results/207-images.jpg...
# Saved real and fake images into stargan/results/208-images.jpg...
# Saved real and fake images into stargan/results/209-images.jpg...
# Saved real and fake images into stargan/results/210-images.jpg...
# Saved real and fake images into stargan/results/211-images.jpg...
# Saved real and fake images into stargan/results/212-images.jpg...
# Saved real and fake images into stargan/results/213-images.jpg...
# Saved real and fake images into stargan/results/214-images.jpg...
# Saved real and fake images into stargan/results/215-images.jpg...
# Saved real and fake images into stargan/results/216-images.jpg...
# Saved real and fake images into stargan/results/217-images.jpg...
# Saved real and fake images into stargan/results/218-images.jpg...
# Saved real and fake images into stargan/results/219-images.jpg...
# Saved real and fake images into stargan/results/220-images.jpg...
# Saved real and fake images into stargan/results/221-images.jpg...
# Saved real and fake images into stargan/results/222-images.jpg...
# Saved real and fake images into stargan/results/223-images.jpg...
# Saved real and fake images into stargan/results/224-images.jpg...
# Saved real and fake images into stargan/results/225-images.jpg...
# Saved real and fake images into stargan/results/226-images.jpg...
# Saved real and fake images into stargan/results/227-images.jpg...
# Saved real and fake images into stargan/results/228-images.jpg...
# Saved real and fake images into stargan/results/229-images.jpg...
# Saved real and fake images into stargan/results/230-images.jpg...
# Saved real and fake images into stargan/results/231-images.jpg...
# Saved real and fake images into stargan/results/232-images.jpg...
# Saved real and fake images into stargan/results/233-images.jpg...
# Saved real and fake images into stargan/results/234-images.jpg...
# Saved real and fake images into stargan/results/235-images.jpg...
# Saved real and fake images into stargan/results/236-images.jpg...
# Saved real and fake images into stargan/results/237-images.jpg...
# Saved real and fake images into stargan/results/238-images.jpg...
# Saved real and fake images into stargan/results/239-images.jpg...
# Saved real and fake images into stargan/results/240-images.jpg...
# Saved real and fake images into stargan/results/241-images.jpg...
# Saved real and fake images into stargan/results/242-images.jpg...
# Saved real and fake images into stargan/results/243-images.jpg...
# Saved real and fake images into stargan/results/244-images.jpg...
# Saved real and fake images into stargan/results/245-images.jpg...
# Saved real and fake images into stargan/results/246-images.jpg...
# Saved real and fake images into stargan/results/247-images.jpg...
# Saved real and fake images into stargan/results/248-images.jpg...
# Saved real and fake images into stargan/results/249-images.jpg...
# Saved real and fake images into stargan/results/250-images.jpg...
# Saved real and fake images into stargan/results/251-images.jpg...
# Saved real and fake images into stargan/results/252-images.jpg...
# Saved real and fake images into stargan/results/253-images.jpg...
# Saved real and fake images into stargan/results/254-images.jpg...
# Saved real and fake images into stargan/results/255-images.jpg...
# Saved real and fake images into stargan/results/256-images.jpg...
# Saved real and fake images into stargan/results/257-images.jpg...
# Saved real and fake images into stargan/results/258-images.jpg...
# Saved real and fake images into stargan/results/259-images.jpg...
# Saved real and fake images into stargan/results/260-images.jpg...
# Saved real and fake images into stargan/results/261-images.jpg...
# Saved real and fake images into stargan/results/262-images.jpg...
# Saved real and fake images into stargan/results/263-images.jpg...
# Saved real and fake images into stargan/results/264-images.jpg...
# Saved real and fake images into stargan/results/265-images.jpg...
# Saved real and fake images into stargan/results/266-images.jpg...
# Saved real and fake images into stargan/results/267-images.jpg...
# Saved real and fake images into stargan/results/268-images.jpg...
# Saved real and fake images into stargan/results/269-images.jpg...
# Saved real and fake images into stargan/results/270-images.jpg...
# Saved real and fake images into stargan/results/271-images.jpg...
# Saved real and fake images into stargan/results/272-images.jpg...
# Saved real and fake images into stargan/results/273-images.jpg...
# Saved real and fake images into stargan/results/274-images.jpg...
# Saved real and fake images into stargan/results/275-images.jpg...
# Saved real and fake images into stargan/results/276-images.jpg...
# Saved real and fake images into stargan/results/277-images.jpg...
# Saved real and fake images into stargan/results/278-images.jpg...
# Saved real and fake images into stargan/results/279-images.jpg...
# Saved real and fake images into stargan/results/280-images.jpg...
# Saved real and fake images into stargan/results/281-images.jpg...
# Saved real and fake images into stargan/results/282-images.jpg...
# Saved real and fake images into stargan/results/283-images.jpg...
# Saved real and fake images into stargan/results/284-images.jpg...
# Saved real and fake images into stargan/results/285-images.jpg...
# Saved real and fake images into stargan/results/286-images.jpg...
# Saved real and fake images into stargan/results/287-images.jpg...
# Saved real and fake images into stargan/results/288-images.jpg...
# Saved real and fake images into stargan/results/289-images.jpg...
# Saved real and fake images into stargan/results/290-images.jpg...
# Saved real and fake images into stargan/results/291-images.jpg...
# Saved real and fake images into stargan/results/292-images.jpg...
# Saved real and fake images into stargan/results/293-images.jpg...
# Saved real and fake images into stargan/results/294-images.jpg...
# Saved real and fake images into stargan/results/295-images.jpg...
# Saved real and fake images into stargan/results/296-images.jpg...
# Saved real and fake images into stargan/results/297-images.jpg...
# Saved real and fake images into stargan/results/298-images.jpg...
# Saved real and fake images into stargan/results/299-images.jpg...
# Saved real and fake images into stargan/results/300-images.jpg...
# Saved real and fake images into stargan/results/301-images.jpg...
# Saved real and fake images into stargan/results/302-images.jpg...
# Saved real and fake images into stargan/results/303-images.jpg...
# Saved real and fake images into stargan/results/304-images.jpg...
# Saved real and fake images into stargan/results/305-images.jpg...
# Saved real and fake images into stargan/results/306-images.jpg...
# Saved real and fake images into stargan/results/307-images.jpg...
# Saved real and fake images into stargan/results/308-images.jpg...
# Saved real and fake images into stargan/results/309-images.jpg...
# Saved real and fake images into stargan/results/310-images.jpg...
# Saved real and fake images into stargan/results/311-images.jpg...
# Saved real and fake images into stargan/results/312-images.jpg...
# Saved real and fake images into stargan/results/313-images.jpg...
# Saved real and fake images into stargan/results/314-images.jpg...
# Saved real and fake images into stargan/results/315-images.jpg...
# Saved real and fake images into stargan/results/316-images.jpg...
# Saved real and fake images into stargan/results/317-images.jpg...
# Saved real and fake images into stargan/results/318-images.jpg...
# Saved real and fake images into stargan/results/319-images.jpg...
# Saved real and fake images into stargan/results/320-images.jpg...
# Saved real and fake images into stargan/results/321-images.jpg...
# Saved real and fake images into stargan/results/322-images.jpg...
# Saved real and fake images into stargan/results/323-images.jpg...
# Saved real and fake images into stargan/results/324-images.jpg...
# Saved real and fake images into stargan/results/325-images.jpg...
# Saved real and fake images into stargan/results/326-images.jpg...
# Saved real and fake images into stargan/results/327-images.jpg...
# Saved real and fake images into stargan/results/328-images.jpg...
# Saved real and fake images into stargan/results/329-images.jpg...
# Saved real and fake images into stargan/results/330-images.jpg...
# Saved real and fake images into stargan/results/331-images.jpg...
# Saved real and fake images into stargan/results/332-images.jpg...
# Saved real and fake images into stargan/results/333-images.jpg...
# Saved real and fake images into stargan/results/334-images.jpg...
# Saved real and fake images into stargan/results/335-images.jpg...
# Saved real and fake images into stargan/results/336-images.jpg...
# Saved real and fake images into stargan/results/337-images.jpg...
# Saved real and fake images into stargan/results/338-images.jpg...
# Saved real and fake images into stargan/results/339-images.jpg...
# Saved real and fake images into stargan/results/340-images.jpg...
# Saved real and fake images into stargan/results/341-images.jpg...
# Saved real and fake images into stargan/results/342-images.jpg...
# Saved real and fake images into stargan/results/343-images.jpg...
# Saved real and fake images into stargan/results/344-images.jpg...
# Saved real and fake images into stargan/results/345-images.jpg...
# Saved real and fake images into stargan/results/346-images.jpg...
# Saved real and fake images into stargan/results/347-images.jpg...
# Saved real and fake images into stargan/results/348-images.jpg...
# Saved real and fake images into stargan/results/349-images.jpg...
# Saved real and fake images into stargan/results/350-images.jpg...
# Saved real and fake images into stargan/results/351-images.jpg...
# Saved real and fake images into stargan/results/352-images.jpg...
# Saved real and fake images into stargan/results/353-images.jpg...
# Saved real and fake images into stargan/results/354-images.jpg...
# Saved real and fake images into stargan/results/355-images.jpg...
# Saved real and fake images into stargan/results/356-images.jpg...
# Saved real and fake images into stargan/results/357-images.jpg...
# Saved real and fake images into stargan/results/358-images.jpg...
# Saved real and fake images into stargan/results/359-images.jpg...
# Saved real and fake images into stargan/results/360-images.jpg...
# Saved real and fake images into stargan/results/361-images.jpg...
# Saved real and fake images into stargan/results/362-images.jpg...
# Saved real and fake images into stargan/results/363-images.jpg...
# Saved real and fake images into stargan/results/364-images.jpg...
# Saved real and fake images into stargan/results/365-images.jpg...
# Saved real and fake images into stargan/results/366-images.jpg...
# Saved real and fake images into stargan/results/367-images.jpg...
# Saved real and fake images into stargan/results/368-images.jpg...
# Saved real and fake images into stargan/results/369-images.jpg...
# Saved real and fake images into stargan/results/370-images.jpg...
# Saved real and fake images into stargan/results/371-images.jpg...
# Saved real and fake images into stargan/results/372-images.jpg...
# Saved real and fake images into stargan/results/373-images.jpg...
# Saved real and fake images into stargan/results/374-images.jpg...
# Saved real and fake images into stargan/results/375-images.jpg...
# Saved real and fake images into stargan/results/376-images.jpg...
# Saved real and fake images into stargan/results/377-images.jpg...
# Saved real and fake images into stargan/results/378-images.jpg...
# Saved real and fake images into stargan/results/379-images.jpg...
# Saved real and fake images into stargan/results/380-images.jpg...
# Saved real and fake images into stargan/results/381-images.jpg...
# Saved real and fake images into stargan/results/382-images.jpg...
# Saved real and fake images into stargan/results/383-images.jpg...
# Saved real and fake images into stargan/results/384-images.jpg...
# Saved real and fake images into stargan/results/385-images.jpg...
# Saved real and fake images into stargan/results/386-images.jpg...
# Saved real and fake images into stargan/results/387-images.jpg...
# Saved real and fake images into stargan/results/388-images.jpg...
# Saved real and fake images into stargan/results/389-images.jpg...
# Saved real and fake images into stargan/results/390-images.jpg...
# Saved real and fake images into stargan/results/391-images.jpg...
# Saved real and fake images into stargan/results/392-images.jpg...
# Saved real and fake images into stargan/results/393-images.jpg...
# Saved real and fake images into stargan/results/394-images.jpg...
# Saved real and fake images into stargan/results/395-images.jpg...
# Saved real and fake images into stargan/results/396-images.jpg...
# Saved real and fake images into stargan/results/397-images.jpg...
# Saved real and fake images into stargan/results/398-images.jpg...
# Saved real and fake images into stargan/results/399-images.jpg...
# Saved real and fake images into stargan/results/400-images.jpg...
# Saved real and fake images into stargan/results/401-images.jpg...
# Saved real and fake images into stargan/results/402-images.jpg...
# Saved real and fake images into stargan/results/403-images.jpg...
# Saved real and fake images into stargan/results/404-images.jpg...
# Saved real and fake images into stargan/results/405-images.jpg...
# Saved real and fake images into stargan/results/406-images.jpg...
# Saved real and fake images into stargan/results/407-images.jpg...
# Saved real and fake images into stargan/results/408-images.jpg...
# Saved real and fake images into stargan/results/409-images.jpg...
# Saved real and fake images into stargan/results/410-images.jpg...
# Saved real and fake images into stargan/results/411-images.jpg...
# Saved real and fake images into stargan/results/412-images.jpg...
# Saved real and fake images into stargan/results/413-images.jpg...
# Saved real and fake images into stargan/results/414-images.jpg...
# Saved real and fake images into stargan/results/415-images.jpg...
# Saved real and fake images into stargan/results/416-images.jpg...
# Saved real and fake images into stargan/results/417-images.jpg...
# Saved real and fake images into stargan/results/418-images.jpg...
# Saved real and fake images into stargan/results/419-images.jpg...
# Saved real and fake images into stargan/results/420-images.jpg...
# Saved real and fake images into stargan/results/421-images.jpg...
# Saved real and fake images into stargan/results/422-images.jpg...
# Saved real and fake images into stargan/results/423-images.jpg...
# Saved real and fake images into stargan/results/424-images.jpg...
# Saved real and fake images into stargan/results/425-images.jpg...
# Saved real and fake images into stargan/results/426-images.jpg...
# Saved real and fake images into stargan/results/427-images.jpg...
# Saved real and fake images into stargan/results/428-images.jpg...
# Saved real and fake images into stargan/results/429-images.jpg...
# Saved real and fake images into stargan/results/430-images.jpg...
# Saved real and fake images into stargan/results/431-images.jpg...
# Saved real and fake images into stargan/results/432-images.jpg...
# Saved real and fake images into stargan/results/433-images.jpg...
# Saved real and fake images into stargan/results/434-images.jpg...
# Saved real and fake images into stargan/results/435-images.jpg...
# Saved real and fake images into stargan/results/436-images.jpg...
# Saved real and fake images into stargan/results/437-images.jpg...
# Saved real and fake images into stargan/results/438-images.jpg...
# Saved real and fake images into stargan/results/439-images.jpg...
# Saved real and fake images into stargan/results/440-images.jpg...
# Saved real and fake images into stargan/results/441-images.jpg...
# Saved real and fake images into stargan/results/442-images.jpg...
# Saved real and fake images into stargan/results/443-images.jpg...
# Saved real and fake images into stargan/results/444-images.jpg...
# Saved real and fake images into stargan/results/445-images.jpg...
# Saved real and fake images into stargan/results/446-images.jpg...
# Saved real and fake images into stargan/results/447-images.jpg...
# Saved real and fake images into stargan/results/448-images.jpg...
# Saved real and fake images into stargan/results/449-images.jpg...
# Saved real and fake images into stargan/results/450-images.jpg...
# Saved real and fake images into stargan/results/451-images.jpg...
# Saved real and fake images into stargan/results/452-images.jpg...
# Saved real and fake images into stargan/results/453-images.jpg...
# Saved real and fake images into stargan/results/454-images.jpg...
# Saved real and fake images into stargan/results/455-images.jpg...
# Saved real and fake images into stargan/results/456-images.jpg...
# Saved real and fake images into stargan/results/457-images.jpg...
# Saved real and fake images into stargan/results/458-images.jpg...
# Saved real and fake images into stargan/results/459-images.jpg...
# Saved real and fake images into stargan/results/460-images.jpg...
# Saved real and fake images into stargan/results/461-images.jpg...
# Saved real and fake images into stargan/results/462-images.jpg...
# Saved real and fake images into stargan/results/463-images.jpg...
# Saved real and fake images into stargan/results/464-images.jpg...
# Saved real and fake images into stargan/results/465-images.jpg...
# Saved real and fake images into stargan/results/466-images.jpg...
# Saved real and fake images into stargan/results/467-images.jpg...
# Saved real and fake images into stargan/results/468-images.jpg...
# Saved real and fake images into stargan/results/469-images.jpg...
# Saved real and fake images into stargan/results/470-images.jpg...
# Saved real and fake images into stargan/results/471-images.jpg...
# Saved real and fake images into stargan/results/472-images.jpg...
# Saved real and fake images into stargan/results/473-images.jpg...
# Saved real and fake images into stargan/results/474-images.jpg...
# Saved real and fake images into stargan/results/475-images.jpg...
# Saved real and fake images into stargan/results/476-images.jpg...
# Saved real and fake images into stargan/results/477-images.jpg...
# Saved real and fake images into stargan/results/478-images.jpg...
# Saved real and fake images into stargan/results/479-images.jpg...
# Saved real and fake images into stargan/results/480-images.jpg...
# Saved real and fake images into stargan/results/481-images.jpg...
# Saved real and fake images into stargan/results/482-images.jpg...
# Saved real and fake images into stargan/results/483-images.jpg...
# Saved real and fake images into stargan/results/484-images.jpg...
# Saved real and fake images into stargan/results/485-images.jpg...
# Saved real and fake images into stargan/results/486-images.jpg...
# Saved real and fake images into stargan/results/487-images.jpg...
# Saved real and fake images into stargan/results/488-images.jpg...
# Saved real and fake images into stargan/results/489-images.jpg...
# Saved real and fake images into stargan/results/490-images.jpg...
# Saved real and fake images into stargan/results/491-images.jpg...
# Saved real and fake images into stargan/results/492-images.jpg...
# Saved real and fake images into stargan/results/493-images.jpg...
# Saved real and fake images into stargan/results/494-images.jpg...
# Saved real and fake images into stargan/results/495-images.jpg...
# Saved real and fake images into stargan/results/496-images.jpg...
# Saved real and fake images into stargan/results/497-images.jpg...
# Saved real and fake images into stargan/results/498-images.jpg...
# Saved real and fake images into stargan/results/499-images.jpg...
# Saved real and fake images into stargan/results/500-images.jpg...
# Saved real and fake images into stargan/results/501-images.jpg...
# Saved real and fake images into stargan/results/502-images.jpg...
# Saved real and fake images into stargan/results/503-images.jpg...
# Saved real and fake images into stargan/results/504-images.jpg...
# Saved real and fake images into stargan/results/505-images.jpg...
# Saved real and fake images into stargan/results/506-images.jpg...
# Saved real and fake images into stargan/results/507-images.jpg...
# Saved real and fake images into stargan/results/508-images.jpg...
# Saved real and fake images into stargan/results/509-images.jpg...
# Saved real and fake images into stargan/results/510-images.jpg...
# Saved real and fake images into stargan/results/511-images.jpg...
# Saved real and fake images into stargan/results/512-images.jpg...
# Saved real and fake images into stargan/results/513-images.jpg...
# Saved real and fake images into stargan/results/514-images.jpg...
# Saved real and fake images into stargan/results/515-images.jpg...
# Saved real and fake images into stargan/results/516-images.jpg...
# Saved real and fake images into stargan/results/517-images.jpg...
# Saved real and fake images into stargan/results/518-images.jpg...
# Saved real and fake images into stargan/results/519-images.jpg...
# Saved real and fake images into stargan/results/520-images.jpg...
# Saved real and fake images into stargan/results/521-images.jpg...
# Saved real and fake images into stargan/results/522-images.jpg...
# Saved real and fake images into stargan/results/523-images.jpg...
# Saved real and fake images into stargan/results/524-images.jpg...
# Saved real and fake images into stargan/results/525-images.jpg...
# Saved real and fake images into stargan/results/526-images.jpg...
# Saved real and fake images into stargan/results/527-images.jpg...
# Saved real and fake images into stargan/results/528-images.jpg...
# Saved real and fake images into stargan/results/529-images.jpg...
# Saved real and fake images into stargan/results/530-images.jpg...
# Saved real and fake images into stargan/results/531-images.jpg...
# Saved real and fake images into stargan/results/532-images.jpg...
# Saved real and fake images into stargan/results/533-images.jpg...
# Saved real and fake images into stargan/results/534-images.jpg...
# Saved real and fake images into stargan/results/535-images.jpg...
# Saved real and fake images into stargan/results/536-images.jpg...
# Saved real and fake images into stargan/results/537-images.jpg...
# Saved real and fake images into stargan/results/538-images.jpg...
# Saved real and fake images into stargan/results/539-images.jpg...
# Saved real and fake images into stargan/results/540-images.jpg...
# Saved real and fake images into stargan/results/541-images.jpg...
# Saved real and fake images into stargan/results/542-images.jpg...
# Saved real and fake images into stargan/results/543-images.jpg...
# Saved real and fake images into stargan/results/544-images.jpg...
# Saved real and fake images into stargan/results/545-images.jpg...
# Saved real and fake images into stargan/results/546-images.jpg...
# Saved real and fake images into stargan/results/547-images.jpg...
# Saved real and fake images into stargan/results/548-images.jpg...
# Saved real and fake images into stargan/results/549-images.jpg...
# Saved real and fake images into stargan/results/550-images.jpg...
# Saved real and fake images into stargan/results/551-images.jpg...
# Saved real and fake images into stargan/results/552-images.jpg...
# Saved real and fake images into stargan/results/553-images.jpg...
# Saved real and fake images into stargan/results/554-images.jpg...
# Saved real and fake images into stargan/results/555-images.jpg...
# Saved real and fake images into stargan/results/556-images.jpg...
# Saved real and fake images into stargan/results/557-images.jpg...
# Saved real and fake images into stargan/results/558-images.jpg...
# Saved real and fake images into stargan/results/559-images.jpg...
# Saved real and fake images into stargan/results/560-images.jpg...
# Saved real and fake images into stargan/results/561-images.jpg...
# Saved real and fake images into stargan/results/562-images.jpg...
# Saved real and fake images into stargan/results/563-images.jpg...
# Saved real and fake images into stargan/results/564-images.jpg...
# Saved real and fake images into stargan/results/565-images.jpg...
# Saved real and fake images into stargan/results/566-images.jpg...
# Saved real and fake images into stargan/results/567-images.jpg...
# Saved real and fake images into stargan/results/568-images.jpg...
# Saved real and fake images into stargan/results/569-images.jpg...
# Saved real and fake images into stargan/results/570-images.jpg...
# Saved real and fake images into stargan/results/571-images.jpg...
# Saved real and fake images into stargan/results/572-images.jpg...
# Saved real and fake images into stargan/results/573-images.jpg...
# Saved real and fake images into stargan/results/574-images.jpg...
# Saved real and fake images into stargan/results/575-images.jpg...
# Saved real and fake images into stargan/results/576-images.jpg...
# Saved real and fake images into stargan/results/577-images.jpg...
# Saved real and fake images into stargan/results/578-images.jpg...
# Saved real and fake images into stargan/results/579-images.jpg...
# Saved real and fake images into stargan/results/580-images.jpg...
# Saved real and fake images into stargan/results/581-images.jpg...
# Saved real and fake images into stargan/results/582-images.jpg...
# Saved real and fake images into stargan/results/583-images.jpg...
# Saved real and fake images into stargan/results/584-images.jpg...
# Saved real and fake images into stargan/results/585-images.jpg...
# Saved real and fake images into stargan/results/586-images.jpg...
# Saved real and fake images into stargan/results/587-images.jpg...
# Saved real and fake images into stargan/results/588-images.jpg...
# Saved real and fake images into stargan/results/589-images.jpg...
# Saved real and fake images into stargan/results/590-images.jpg...
# Saved real and fake images into stargan/results/591-images.jpg...
# Saved real and fake images into stargan/results/592-images.jpg...
# Saved real and fake images into stargan/results/593-images.jpg...
# Saved real and fake images into stargan/results/594-images.jpg...
# Saved real and fake images into stargan/results/595-images.jpg...
# Saved real and fake images into stargan/results/596-images.jpg...
# Saved real and fake images into stargan/results/597-images.jpg...
# Saved real and fake images into stargan/results/598-images.jpg...
# Saved real and fake images into stargan/results/599-images.jpg...
# Saved real and fake images into stargan/results/600-images.jpg...
# Saved real and fake images into stargan/results/601-images.jpg...
# Saved real and fake images into stargan/results/602-images.jpg...
# Saved real and fake images into stargan/results/603-images.jpg...
# Saved real and fake images into stargan/results/604-images.jpg...
# Saved real and fake images into stargan/results/605-images.jpg...
# Saved real and fake images into stargan/results/606-images.jpg...
# Saved real and fake images into stargan/results/607-images.jpg...
# Saved real and fake images into stargan/results/608-images.jpg...
# Saved real and fake images into stargan/results/609-images.jpg...
# Saved real and fake images into stargan/results/610-images.jpg...
# Saved real and fake images into stargan/results/611-images.jpg...
# Saved real and fake images into stargan/results/612-images.jpg...
# Saved real and fake images into stargan/results/613-images.jpg...
# Saved real and fake images into stargan/results/614-images.jpg...
# Saved real and fake images into stargan/results/615-images.jpg...
# Saved real and fake images into stargan/results/616-images.jpg...
# Saved real and fake images into stargan/results/617-images.jpg...
# Saved real and fake images into stargan/results/618-images.jpg...
# Saved real and fake images into stargan/results/619-images.jpg...
# Saved real and fake images into stargan/results/620-images.jpg...
# Saved real and fake images into stargan/results/621-images.jpg...
# Saved real and fake images into stargan/results/622-images.jpg...
# Saved real and fake images into stargan/results/623-images.jpg...
# Saved real and fake images into stargan/results/624-images.jpg...
# Saved real and fake images into stargan/results/625-images.jpg...
# Saved real and fake images into stargan/results/626-images.jpg...
# Saved real and fake images into stargan/results/627-images.jpg...
# Saved real and fake images into stargan/results/628-images.jpg...
# Saved real and fake images into stargan/results/629-images.jpg...
# Saved real and fake images into stargan/results/630-images.jpg...
# Saved real and fake images into stargan/results/631-images.jpg...
# Saved real and fake images into stargan/results/632-images.jpg...
# Saved real and fake images into stargan/results/633-images.jpg...
# Saved real and fake images into stargan/results/634-images.jpg...
# Saved real and fake images into stargan/results/635-images.jpg...
# Saved real and fake images into stargan/results/636-images.jpg...
# Saved real and fake images into stargan/results/637-images.jpg...
# Saved real and fake images into stargan/results/638-images.jpg...
# Saved real and fake images into stargan/results/639-images.jpg...
# Saved real and fake images into stargan/results/640-images.jpg...
# Saved real and fake images into stargan/results/641-images.jpg...
# Saved real and fake images into stargan/results/642-images.jpg...
# Saved real and fake images into stargan/results/643-images.jpg...
# Saved real and fake images into stargan/results/644-images.jpg...
# Saved real and fake images into stargan/results/645-images.jpg...
# Saved real and fake images into stargan/results/646-images.jpg...
# Saved real and fake images into stargan/results/647-images.jpg...
# Saved real and fake images into stargan/results/648-images.jpg...
# Saved real and fake images into stargan/results/649-images.jpg...
# Saved real and fake images into stargan/results/650-images.jpg...
# Saved real and fake images into stargan/results/651-images.jpg...
# Saved real and fake images into stargan/results/652-images.jpg...
# Saved real and fake images into stargan/results/653-images.jpg...
# Saved real and fake images into stargan/results/654-images.jpg...
# Saved real and fake images into stargan/results/655-images.jpg...
# Saved real and fake images into stargan/results/656-images.jpg...
# Saved real and fake images into stargan/results/657-images.jpg...
# Saved real and fake images into stargan/results/658-images.jpg...
# Saved real and fake images into stargan/results/659-images.jpg...
# Saved real and fake images into stargan/results/660-images.jpg...
# Saved real and fake images into stargan/results/661-images.jpg...
# Saved real and fake images into stargan/results/662-images.jpg...
# Saved real and fake images into stargan/results/663-images.jpg...
# Saved real and fake images into stargan/results/664-images.jpg...
# Saved real and fake images into stargan/results/665-images.jpg...
# Saved real and fake images into stargan/results/666-images.jpg...
# Saved real and fake images into stargan/results/667-images.jpg...
# Saved real and fake images into stargan/results/668-images.jpg...
# Saved real and fake images into stargan/results/669-images.jpg...
# Saved real and fake images into stargan/results/670-images.jpg...
# Saved real and fake images into stargan/results/671-images.jpg...
# Saved real and fake images into stargan/results/672-images.jpg...
# Saved real and fake images into stargan/results/673-images.jpg...
# Saved real and fake images into stargan/results/674-images.jpg...
# Saved real and fake images into stargan/results/675-images.jpg...
# Saved real and fake images into stargan/results/676-images.jpg...
# Saved real and fake images into stargan/results/677-images.jpg...
# Saved real and fake images into stargan/results/678-images.jpg...
# Saved real and fake images into stargan/results/679-images.jpg...
# Saved real and fake images into stargan/results/680-images.jpg...
# Saved real and fake images into stargan/results/681-images.jpg...
# Saved real and fake images into stargan/results/682-images.jpg...
# Saved real and fake images into stargan/results/683-images.jpg...
# Saved real and fake images into stargan/results/684-images.jpg...
# Saved real and fake images into stargan/results/685-images.jpg...
# Saved real and fake images into stargan/results/686-images.jpg...
# Saved real and fake images into stargan/results/687-images.jpg...
# Saved real and fake images into stargan/results/688-images.jpg...
# Saved real and fake images into stargan/results/689-images.jpg...
# Saved real and fake images into stargan/results/690-images.jpg...
# Saved real and fake images into stargan/results/691-images.jpg...
# Saved real and fake images into stargan/results/692-images.jpg...
# Saved real and fake images into stargan/results/693-images.jpg...
# Saved real and fake images into stargan/results/694-images.jpg...
# Saved real and fake images into stargan/results/695-images.jpg...
# Saved real and fake images into stargan/results/696-images.jpg...
# Saved real and fake images into stargan/results/697-images.jpg...
# Saved real and fake images into stargan/results/698-images.jpg...
# Saved real and fake images into stargan/results/699-images.jpg...
# Saved real and fake images into stargan/results/700-images.jpg...
# Saved real and fake images into stargan/results/701-images.jpg...
# Saved real and fake images into stargan/results/702-images.jpg...
# Saved real and fake images into stargan/results/703-images.jpg...
# Saved real and fake images into stargan/results/704-images.jpg...
# Saved real and fake images into stargan/results/705-images.jpg...
# Saved real and fake images into stargan/results/706-images.jpg...
# Saved real and fake images into stargan/results/707-images.jpg...
# Saved real and fake images into stargan/results/708-images.jpg...
# Saved real and fake images into stargan/results/709-images.jpg...
# Saved real and fake images into stargan/results/710-images.jpg...
# Saved real and fake images into stargan/results/711-images.jpg...
# Saved real and fake images into stargan/results/712-images.jpg...
# Saved real and fake images into stargan/results/713-images.jpg...
# Saved real and fake images into stargan/results/714-images.jpg...
# Saved real and fake images into stargan/results/715-images.jpg...
# Saved real and fake images into stargan/results/716-images.jpg...
# Saved real and fake images into stargan/results/717-images.jpg...
# Saved real and fake images into stargan/results/718-images.jpg...
# Saved real and fake images into stargan/results/719-images.jpg...
# Saved real and fake images into stargan/results/720-images.jpg...
# Saved real and fake images into stargan/results/721-images.jpg...
# Saved real and fake images into stargan/results/722-images.jpg...
# Saved real and fake images into stargan/results/723-images.jpg...
# Saved real and fake images into stargan/results/724-images.jpg...
# Saved real and fake images into stargan/results/725-images.jpg...
# Saved real and fake images into stargan/results/726-images.jpg...
# Saved real and fake images into stargan/results/727-images.jpg...
# Saved real and fake images into stargan/results/728-images.jpg...
# Saved real and fake images into stargan/results/729-images.jpg...
# Saved real and fake images into stargan/results/730-images.jpg...
# Saved real and fake images into stargan/results/731-images.jpg...
# Saved real and fake images into stargan/results/732-images.jpg...
# Saved real and fake images into stargan/results/733-images.jpg...
# Saved real and fake images into stargan/results/734-images.jpg...
# Saved real and fake images into stargan/results/735-images.jpg...
# Saved real and fake images into stargan/results/736-images.jpg...
# Saved real and fake images into stargan/results/737-images.jpg...
# Saved real and fake images into stargan/results/738-images.jpg...
# Saved real and fake images into stargan/results/739-images.jpg...
# Saved real and fake images into stargan/results/740-images.jpg...
# Saved real and fake images into stargan/results/741-images.jpg...
# Saved real and fake images into stargan/results/742-images.jpg...
# Saved real and fake images into stargan/results/743-images.jpg...
# Saved real and fake images into stargan/results/744-images.jpg...
# Saved real and fake images into stargan/results/745-images.jpg...
# Saved real and fake images into stargan/results/746-images.jpg...
# Saved real and fake images into stargan/results/747-images.jpg...
# Saved real and fake images into stargan/results/748-images.jpg...
# Saved real and fake images into stargan/results/749-images.jpg...
# Saved real and fake images into stargan/results/750-images.jpg...
# Saved real and fake images into stargan/results/751-images.jpg...
# Saved real and fake images into stargan/results/752-images.jpg...
# Saved real and fake images into stargan/results/753-images.jpg...
# Saved real and fake images into stargan/results/754-images.jpg...
# Saved real and fake images into stargan/results/755-images.jpg...
# Saved real and fake images into stargan/results/756-images.jpg...
# Saved real and fake images into stargan/results/757-images.jpg...
# Saved real and fake images into stargan/results/758-images.jpg...
# Saved real and fake images into stargan/results/759-images.jpg...
# Saved real and fake images into stargan/results/760-images.jpg...
# Saved real and fake images into stargan/results/761-images.jpg...
# Saved real and fake images into stargan/results/762-images.jpg...
# Saved real and fake images into stargan/results/763-images.jpg...
# Saved real and fake images into stargan/results/764-images.jpg...
# Saved real and fake images into stargan/results/765-images.jpg...
# Saved real and fake images into stargan/results/766-images.jpg...
# Saved real and fake images into stargan/results/767-images.jpg...
# Saved real and fake images into stargan/results/768-images.jpg...
# Saved real and fake images into stargan/results/769-images.jpg...
# Saved real and fake images into stargan/results/770-images.jpg...
# Saved real and fake images into stargan/results/771-images.jpg...
# Saved real and fake images into stargan/results/772-images.jpg...
# Saved real and fake images into stargan/results/773-images.jpg...
# Saved real and fake images into stargan/results/774-images.jpg...
# Saved real and fake images into stargan/results/775-images.jpg...
# Saved real and fake images into stargan/results/776-images.jpg...
# Saved real and fake images into stargan/results/777-images.jpg...
# Saved real and fake images into stargan/results/778-images.jpg...
# Saved real and fake images into stargan/results/779-images.jpg...
# Saved real and fake images into stargan/results/780-images.jpg...
# Saved real and fake images into stargan/results/781-images.jpg...
# Saved real and fake images into stargan/results/782-images.jpg...
# Saved real and fake images into stargan/results/783-images.jpg...
# Saved real and fake images into stargan/results/784-images.jpg...
# Saved real and fake images into stargan/results/785-images.jpg...
# Saved real and fake images into stargan/results/786-images.jpg...
# Saved real and fake images into stargan/results/787-images.jpg...
# Saved real and fake images into stargan/results/788-images.jpg...
# Saved real and fake images into stargan/results/789-images.jpg...
# Saved real and fake images into stargan/results/790-images.jpg...
# Saved real and fake images into stargan/results/791-images.jpg...
# Saved real and fake images into stargan/results/792-images.jpg...
# Saved real and fake images into stargan/results/793-images.jpg...
# Saved real and fake images into stargan/results/794-images.jpg...
# Saved real and fake images into stargan/results/795-images.jpg...
# Saved real and fake images into stargan/results/796-images.jpg...
# Saved real and fake images into stargan/results/797-images.jpg...

# %% [markdown]
# ### Move checkpoints to local

# %%
# !cp -r stargan/ drive/MyDrive/Colab\ Notebooks/StarGAN/checkpoints/

# %% [markdown]
# ## Todo
#
# Run this notebook and find a way to reformat the output into individual photos.
